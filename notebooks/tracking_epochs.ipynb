# %% [markdown]
# ## `STAGE 1 Training - 01/24/2026`

# %%
Epoch 1/15
50/50 ━━━━━━━━━━━━━━━━━━━━ 48s 820ms/step - accuracy: 0.6500 - loss: 0.6681 - precision: 0.6527 - recall: 0.6413 - val_accuracy: 0.7750 - val_loss: 0.4718 - val_precision: 0.7570 - val_recall: 0.8100
Epoch 2/15
50/50 ━━━━━━━━━━━━━━━━━━━━ 32s 625ms/step - accuracy: 0.7788 - loss: 0.4504 - precision: 0.7760 - recall: 0.7837 - val_accuracy: 0.8250 - val_loss: 0.3781 - val_precision: 0.7876 - val_recall: 0.8900
Epoch 3/15
50/50 ━━━━━━━━━━━━━━━━━━━━ 32s 636ms/step - accuracy: 0.8325 - loss: 0.3662 - precision: 0.8174 - recall: 0.8562 - val_accuracy: 0.8750 - val_loss: 0.3186 - val_precision: 0.8319 - val_recall: 0.9400
Epoch 4/15
50/50 ━━━━━━━━━━━━━━━━━━━━ 32s 625ms/step - accuracy: 0.8687 - loss: 0.3088 - precision: 0.8633 - recall: 0.8763 - val_accuracy: 0.8750 - val_loss: 0.2989 - val_precision: 0.8319 - val_recall: 0.9400
Epoch 5/15
50/50 ━━━━━━━━━━━━━━━━━━━━ 32s 632ms/step - accuracy: 0.8769 - loss: 0.2986 - precision: 0.8619 - recall: 0.8975 - val_accuracy: 0.8750 - val_loss: 0.2885 - val_precision: 0.8378 - val_recall: 0.9300
Epoch 6/15
50/50 ━━━━━━━━━━━━━━━━━━━━ 35s 677ms/step - accuracy: 0.8863 - loss: 0.2767 - precision: 0.8750 - recall: 0.9013 - val_accuracy: 0.8850 - val_loss: 0.2645 - val_precision: 0.8598 - val_recall: 0.9200
Epoch 7/15
50/50 ━━━━━━━━━━━━━━━━━━━━ 32s 625ms/step - accuracy: 0.8850 - loss: 0.2616 - precision: 0.8869 - recall: 0.8825 - val_accuracy: 0.8650 - val_loss: 0.2656 - val_precision: 0.8288 - val_recall: 0.9200
Epoch 8/15
50/50 ━━━━━━━━━━━━━━━━━━━━ 32s 634ms/step - accuracy: 0.9125 - loss: 0.2359 - precision: 0.8995 - recall: 0.9287 - val_accuracy: 0.8750 - val_loss: 0.2578 - val_precision: 0.8440 - val_recall: 0.9200
Epoch 9/15
50/50 ━━━━━━━━━━━━━━━━━━━━ 32s 629ms/step - accuracy: 0.9119 - loss: 0.2297 - precision: 0.9063 - recall: 0.9187 - val_accuracy: 0.8800 - val_loss: 0.2491 - val_precision: 0.8455 - val_recall: 0.9300
Epoch 10/15
50/50 ━━━━━━━━━━━━━━━━━━━━ 41s 614ms/step - accuracy: 0.9106 - loss: 0.2220 - precision: 0.9091 - recall: 0.9125 - val_accuracy: 0.8850 - val_loss: 0.2294 - val_precision: 0.8667 - val_recall: 0.9100
Epoch 11/15
50/50 ━━━━━━━━━━━━━━━━━━━━ 33s 646ms/step - accuracy: 0.9281 - loss: 0.2015 - precision: 0.9244 - recall: 0.9325 - val_accuracy: 0.8850 - val_loss: 0.2243 - val_precision: 0.8667 - val_recall: 0.9100
Epoch 12/15
50/50 ━━━━━━━━━━━━━━━━━━━━ 34s 661ms/step - accuracy: 0.9225 - loss: 0.2064 - precision: 0.9204 - recall: 0.9250 - val_accuracy: 0.8900 - val_loss: 0.2195 - val_precision: 0.8679 - val_recall: 0.9200
Epoch 13/15
50/50 ━━━━━━━━━━━━━━━━━━━━ 32s 636ms/step - accuracy: 0.9275 - loss: 0.1935 - precision: 0.9264 - recall: 0.9287 - val_accuracy: 0.9000 - val_loss: 0.2058 - val_precision: 0.8846 - val_recall: 0.9200
Epoch 14/15
50/50 ━━━━━━━━━━━━━━━━━━━━ 32s 632ms/step - accuracy: 0.9225 - loss: 0.2014 - precision: 0.9194 - recall: 0.9262 - val_accuracy: 0.8900 - val_loss: 0.2069 - val_precision: 0.8679 - val_recall: 0.9200
Epoch 15/15
50/50 ━━━━━━━━━━━━━━━━━━━━ 43s 675ms/step - accuracy: 0.9287 - loss: 0.1922 - precision: 0.9224 - recall: 0.9362 - val_accuracy: 0.8950 - val_loss: 0.2103 - val_precision: 0.8692 - val_recall: 0.9300

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > TEST DATASET
#
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 462ms/step
# - accuracy: 0.9150
# - loss: 0.1811
# - precision: 0.9560
# - recall: 0.8700

# %% [markdown]
# ___Stage 1 Training Analysis___
#
# **Epochs:** 15
#
# ---
#
# ### Training Performance Trend
#
# - Training accuracy improved steadily from **65.0% (Epoch 1)** to **~92.9% (Epoch 15)**.
# - Training loss decreased consistently from **0.668 → ~0.192**, indicating stable convergence.
# - Precision and recall both increased throughout training, reaching **~0.92–0.94** by the final epochs.
# - No sudden metric drops were observed, suggesting smooth and stable optimization.
#
# __Interpretation:__
# `The model learned discriminative features effectively and converged without instability.`
#
# ---
#
# ### Validation Performance Trend
#
# - Validation accuracy rose quickly from **77.5% (Epoch 1)** to **~87.5% by Epoch 3**, then gradually improved.
# - Peak validation accuracy reached **90.0% (Epoch 13)** and remained stable around **89–90%** afterward.
# - Validation loss decreased from **0.472 → ~0.206**, with minor fluctuations in later epochs.
# - Validation precision (~0.87–0.88) and recall (~0.92–0.93) remained high and consistent.
#
# __Interpretation:__
# `The model generalizes well to unseen data, with stable validation metrics and no sharp degradation.`
#
# ---
#
# ### Overfitting Assessment
#
# - Training accuracy continued to increase slightly after **Epoch ~10**, while validation accuracy plateaued.
# - Validation loss remained low and stable, without a sustained upward trend.
# - The training–validation accuracy gap stayed moderate (**~3–4%**).
#
# __Conclusion:__
# `Only mild overfitting is observed, and it does not negatively impact validation performance.`
#
# ---
#
# ### Optimal Epoch Selection
#
# - Best balance between performance and generalization occurs around **Epochs 12–13**:
#   - Validation accuracy peaks at **~90.0%**
#   - Validation loss is near its minimum (**~0.206**)
# - Beyond this range, improvements are marginal and mostly confined to training metrics.
#
# __Recommended Optimal Epoch:__
# `Epoch 12–13, where validation performance is strongest without unnecessary overfitting.`
#
# ---
#
# ### Test Dataset Performance
#
# - **Test Accuracy:** 91.5%
# - **Test Precision:** 95.6%
# - **Test Recall:** 87.0%
# - **Test Loss:** 0.1811
#
# __Interpretation:__
# `The test results confirm strong real-world generalization, with particularly high precision and slightly lower recall, indicating a conservative but reliable classification behavior.`

# %% [markdown]
# ## `Stage 3 Paper Training - 01/24/2026`

# %%
Epoch 1/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 101s 1s/step - accuracy: 0.4440 - loss: 1.5203 - precision: 0.5040 - recall: 0.3165 - val_accuracy: 0.7600 - val_loss: 0.7430 - val_precision: 0.8875 - val_recall: 0.5680
Epoch 2/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.6915 - loss: 0.8595 - precision: 0.7601 - recall: 0.6035 - val_accuracy: 0.8320 - val_loss: 0.5214 - val_precision: 0.9307 - val_recall: 0.7520
Epoch 3/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.7480 - loss: 0.6864 - precision: 0.8045 - recall: 0.6770 - val_accuracy: 0.8600 - val_loss: 0.4334 - val_precision: 0.9128 - val_recall: 0.7960
Epoch 4/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.7815 - loss: 0.5722 - precision: 0.8275 - recall: 0.7365 - val_accuracy: 0.8680 - val_loss: 0.3891 - val_precision: 0.9079 - val_recall: 0.8280
Epoch 5/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.8105 - loss: 0.5063 - precision: 0.8516 - recall: 0.7690 - val_accuracy: 0.8720 - val_loss: 0.3568 - val_precision: 0.9060 - val_recall: 0.8480
Epoch 6/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.8210 - loss: 0.4744 - precision: 0.8604 - recall: 0.7825 - val_accuracy: 0.8720 - val_loss: 0.3383 - val_precision: 0.8945 - val_recall: 0.8480
Epoch 7/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.8575 - loss: 0.4031 - precision: 0.8888 - recall: 0.8195 - val_accuracy: 0.8760 - val_loss: 0.3172 - val_precision: 0.8992 - val_recall: 0.8560
Epoch 8/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.8655 - loss: 0.3731 - precision: 0.8948 - recall: 0.8375 - val_accuracy: 0.8720 - val_loss: 0.2995 - val_precision: 0.9145 - val_recall: 0.8560
Epoch 9/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.8655 - loss: 0.3573 - precision: 0.8947 - recall: 0.8450 - val_accuracy: 0.8880 - val_loss: 0.2870 - val_precision: 0.9114 - val_recall: 0.8640
Epoch 10/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.8845 - loss: 0.3260 - precision: 0.9061 - recall: 0.8535 - val_accuracy: 0.8880 - val_loss: 0.2758 - val_precision: 0.9118 - val_recall: 0.8680
Epoch 11/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.8710 - loss: 0.3328 - precision: 0.8946 - recall: 0.8485 - val_accuracy: 0.8920 - val_loss: 0.2660 - val_precision: 0.9156 - val_recall: 0.8680
Epoch 12/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.8905 - loss: 0.2991 - precision: 0.9091 - recall: 0.8700 - val_accuracy: 0.8960 - val_loss: 0.2700 - val_precision: 0.9076 - val_recall: 0.8640
Epoch 13/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.8990 - loss: 0.2824 - precision: 0.9174 - recall: 0.8770 - val_accuracy: 0.8960 - val_loss: 0.2555 - val_precision: 0.9244 - val_recall: 0.8800
Epoch 14/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9035 - loss: 0.2702 - precision: 0.9232 - recall: 0.8775 - val_accuracy: 0.9000 - val_loss: 0.2492 - val_precision: 0.9247 - val_recall: 0.8840
Epoch 15/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9080 - loss: 0.2572 - precision: 0.9280 - recall: 0.8890 - val_accuracy: 0.9040 - val_loss: 0.2481 - val_precision: 0.9167 - val_recall: 0.8800
Epoch 16/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.9110 - loss: 0.2534 - precision: 0.9253 - recall: 0.8920 - val_accuracy: 0.9080 - val_loss: 0.2343 - val_precision: 0.9292 - val_recall: 0.8920
Epoch 17/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.9160 - loss: 0.2284 - precision: 0.9284 - recall: 0.9005 - val_accuracy: 0.9160 - val_loss: 0.2307 - val_precision: 0.9259 - val_recall: 0.9000
Epoch 18/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.9300 - loss: 0.2136 - precision: 0.9400 - recall: 0.9160 - val_accuracy: 0.9080 - val_loss: 0.2338 - val_precision: 0.9298 - val_recall: 0.9000
Epoch 19/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 127s 2s/step - accuracy: 0.9210 - loss: 0.2239 - precision: 0.9346 - recall: 0.9080 - val_accuracy: 0.9240 - val_loss: 0.2347 - val_precision: 0.9300 - val_recall: 0.9040
Epoch 20/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 100s 2s/step - accuracy: 0.9275 - loss: 0.2118 - precision: 0.9387 - recall: 0.9110 - val_accuracy: 0.9160 - val_loss: 0.2396 - val_precision: 0.9221 - val_recall: 0.9000
Epoch 21/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 111s 2s/step - accuracy: 0.9355 - loss: 0.1990 - precision: 0.9466 - recall: 0.9220 - val_accuracy: 0.9160 - val_loss: 0.2307 - val_precision: 0.9303 - val_recall: 0.9080
Epoch 22/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.9380 - loss: 0.1913 - precision: 0.9474 - recall: 0.9270 - val_accuracy: 0.9160 - val_loss: 0.2295 - val_precision: 0.9259 - val_recall: 0.9000
Epoch 23/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step - accuracy: 0.9340 - loss: 0.1840 - precision: 0.9469 - recall: 0.9185 - val_accuracy: 0.9120 - val_loss: 0.2237 - val_precision: 0.9146 - val_recall: 0.9000
Epoch 24/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9300 - loss: 0.1951 - precision: 0.9421 - recall: 0.9190 - val_accuracy: 0.9120 - val_loss: 0.2208 - val_precision: 0.9303 - val_recall: 0.9080
Epoch 25/25
63/63 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - accuracy: 0.9370 - loss: 0.1762 - precision: 0.9459 - recall: 0.9265 - val_accuracy: 0.9160 - val_loss: 0.2178 - val_precision: 0.9228 - val_recall: 0.9080

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > TEST DATASET
#
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step
# - accuracy: 0.8440
# - loss: 0.3412
# - precision: 0.8595
# - recall: 0.8320

# %% [markdown]
# ___Stage 3 (PAPER) Training Analysis___
#
# **Epochs:** 25
#
# ---
#
# ### Training Performance Trend
#
# - Training accuracy increased steadily from 44.4% (Epoch 1) to ~93–94% (Epochs 21–25).
# - Training loss consistently decreased from 1.52 to ~0.18, indicating stable convergence.
# - Precision and recall both improved steadily, showing balanced learning rather than accuracy inflation.
#
# __Interpretation:__ `The model successfully learned discriminative features throughout training without instability.`
#
# ---
#
# ### Validation Performance Trend
#
# - Validation accuracy improved rapidly, reaching ~87% by Epoch 5 and stabilizing between 91–92% afterward.
# - Lowest validation loss occurred near the final epochs (~0.218).
# - Validation precision (~0.92–0.93) and recall (~0.90–0.91) remained high and stable.
#
# __Interpretation:__
# `The model generalized well to unseen data, with no sharp degradation in validation metrics.`
#
# ---
#
# ### Overfitting Assessment
#
# - Training accuracy continued to increase slightly after Epoch ~18, while validation accuracy plateaued.
# - Validation loss remained stable and did not increase sharply.
# - The training–validation gap stayed moderate (~2–3%).
#
# __Conclusion:__
# `Only minor overfitting is observed; it is not severe enough to invalidate the model.`
#
# ---
#
# ### Optimal Epoch Selection
#
# - Best balance between accuracy and loss occurs around Epochs 19–22.
# - After this range:
#     - Training accuracy continues to rise
#     - Validation gains become marginal
#
# __Recommended Optimal Epoch:__
# `Epoch 19–21, where validation accuracy peaks (~92.4%) without unnecessary overfitting.`
#
# ---
#
# ### Test Dataset Performance
# - Test Accuracy: 84.4%
# - Test Precision: 85.95%
# - Test Recall: 83.20%
# - Test Loss: 0.3412
#
# __Interpretation:__
# `The performance drop from validation to test data is expected and acceptable, confirming reasonable real-world generalization.`

# %% [markdown]
# ## `Stage 3 Glass : 01/24/2026`

# %%
Epoch 1/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.6800 - loss: 0.7843 - precision: 0.7016 - recall: 0.6525 - val_accuracy: 0.0600 - val_loss: 3.5612 - val_precision: 0.0604 - val_recall: 0.0600
Epoch 2/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 30s 785ms/step - accuracy: 0.8858 - loss: 0.2903 - precision: 0.9033 - recall: 0.8717 - val_accuracy: 0.0400 - val_loss: 4.8145 - val_precision: 0.0338 - val_recall: 0.0333
Epoch 3/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 30s 790ms/step - accuracy: 0.9275 - loss: 0.2043 - precision: 0.9333 - recall: 0.9217 - val_accuracy: 0.0333 - val_loss: 5.4697 - val_precision: 0.0333 - val_recall: 0.0333
Epoch 4/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 31s 800ms/step - accuracy: 0.9358 - loss: 0.1910 - precision: 0.9419 - recall: 0.9317 - val_accuracy: 0.0333 - val_loss: 5.9111 - val_precision: 0.0333 - val_recall: 0.0333
Epoch 5/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 31s 803ms/step - accuracy: 0.9575 - loss: 0.1262 - precision: 0.9605 - recall: 0.9525 - val_accuracy: 0.0333 - val_loss: 6.3266 - val_precision: 0.0333 - val_recall: 0.0333
Epoch 6/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 31s 814ms/step - accuracy: 0.9592 - loss: 0.1253 - precision: 0.9613 - recall: 0.9533 - val_accuracy: 0.0267 - val_loss: 6.6286 - val_precision: 0.0268 - val_recall: 0.0267
Epoch 7/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 32s 831ms/step - accuracy: 0.9683 - loss: 0.0961 - precision: 0.9716 - recall: 0.9683 - val_accuracy: 0.0200 - val_loss: 6.9300 - val_precision: 0.0201 - val_recall: 0.0200
Epoch 8/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 32s 837ms/step - accuracy: 0.9767 - loss: 0.0857 - precision: 0.9783 - recall: 0.9750 - val_accuracy: 0.0200 - val_loss: 7.2472 - val_precision: 0.0200 - val_recall: 0.0200
Epoch 9/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 31s 823ms/step - accuracy: 0.9733 - loss: 0.0877 - precision: 0.9749 - recall: 0.9725 - val_accuracy: 0.0200 - val_loss: 7.5281 - val_precision: 0.0200 - val_recall: 0.0200
Epoch 10/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9817 - loss: 0.0722 - precision: 0.9817 - recall: 0.9817 - val_accuracy: 0.0200 - val_loss: 7.7815 - val_precision: 0.0200 - val_recall: 0.0200
Epoch 11/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 34s 880ms/step - accuracy: 0.9783 - loss: 0.0565 - precision: 0.9783 - recall: 0.9750 - val_accuracy: 0.0200 - val_loss: 8.0037 - val_precision: 0.0200 - val_recall: 0.0200
Epoch 12/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 31s 808ms/step - accuracy: 0.9867 - loss: 0.0538 - precision: 0.9891 - recall: 0.9842 - val_accuracy: 0.0333 - val_loss: 8.2534 - val_precision: 0.0333 - val_recall: 0.0333
Epoch 13/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 30s 796ms/step - accuracy: 0.9858 - loss: 0.0449 - precision: 0.9875 - recall: 0.9850 - val_accuracy: 0.0267 - val_loss: 8.4321 - val_precision: 0.0267 - val_recall: 0.0267
Epoch 14/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 31s 821ms/step - accuracy: 0.9833 - loss: 0.0497 - precision: 0.9833 - recall: 0.9825 - val_accuracy: 0.0267 - val_loss: 8.5926 - val_precision: 0.0267 - val_recall: 0.0267
Epoch 15/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 31s 813ms/step - accuracy: 0.9883 - loss: 0.0418 - precision: 0.9900 - recall: 0.9875 - val_accuracy: 0.0267 - val_loss: 8.7213 - val_precision: 0.0267 - val_recall: 0.0267
Epoch 16/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 31s 825ms/step - accuracy: 0.9875 - loss: 0.0468 - precision: 0.9875 - recall: 0.9867 - val_accuracy: 0.0267 - val_loss: 8.7949 - val_precision: 0.0267 - val_recall: 0.0267
Epoch 17/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 31s 820ms/step - accuracy: 0.9892 - loss: 0.0368 - precision: 0.9892 - recall: 0.9892 - val_accuracy: 0.0267 - val_loss: 8.9891 - val_precision: 0.0267 - val_recall: 0.0267
Epoch 18/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 31s 820ms/step - accuracy: 0.9875 - loss: 0.0381 - precision: 0.9883 - recall: 0.9875 - val_accuracy: 0.0200 - val_loss: 9.1747 - val_precision: 0.0200 - val_recall: 0.0200
Epoch 19/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 31s 816ms/step - accuracy: 0.9892 - loss: 0.0339 - precision: 0.9892 - recall: 0.9892 - val_accuracy: 0.0200 - val_loss: 9.3468 - val_precision: 0.0200 - val_recall: 0.0200
Epoch 20/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 173s 5s/step - accuracy: 0.9917 - loss: 0.0300 - precision: 0.9917 - recall: 0.9908 - val_accuracy: 0.0200 - val_loss: 9.5158 - val_precision: 0.0200 - val_recall: 0.0200
Epoch 21/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 30s 802ms/step - accuracy: 0.9858 - loss: 0.0358 - precision: 0.9875 - recall: 0.9858 - val_accuracy: 0.0200 - val_loss: 9.6115 - val_precision: 0.0200 - val_recall: 0.0200
Epoch 22/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 30s 793ms/step - accuracy: 0.9858 - loss: 0.0425 - precision: 0.9858 - recall: 0.9858 - val_accuracy: 0.0200 - val_loss: 9.6397 - val_precision: 0.0200 - val_recall: 0.0200
Epoch 23/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 31s 807ms/step - accuracy: 0.9925 - loss: 0.0257 - precision: 0.9925 - recall: 0.9925 - val_accuracy: 0.0133 - val_loss: 9.7656 - val_precision: 0.0133 - val_recall: 0.0133
Epoch 24/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 31s 817ms/step - accuracy: 0.9950 - loss: 0.0217 - precision: 0.9950 - recall: 0.9950 - val_accuracy: 0.0133 - val_loss: 9.9290 - val_precision: 0.0133 - val_recall: 0.0133
Epoch 25/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 32s 847ms/step - accuracy: 0.9983 - loss: 0.0188 - precision: 0.9983 - recall: 0.9983 - val_accuracy: 0.0133 - val_loss: 10.0434 - val_precision: 0.0133 - val_recall: 0.0133

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > TEST DATASET
#
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 712ms/step
# - accuracy: 0.3400
# - loss: 5.8641
# - precision: 0.3423
# - recall: 0.3400

# %% [markdown]
# ___Stage Training Analysis (Multi-Class Classification)___
#
# **Epochs:** 25
#
# ---
#
# ### Training Performance Trend
#
# - Training accuracy increased rapidly from **68.0% (Epoch 1)** to **~99.8% (Epoch 25)**.
# - Training loss dropped sharply from **0.784 → ~0.019**, indicating extreme memorization of the training data.
# - Precision and recall reached near-perfect values (**~0.99**) after the early epochs.
# - The training metrics suggest **over-optimization rather than meaningful generalization**.
#
# __Interpretation:__
# `The model severely overfitted the training dataset, effectively memorizing samples instead of learning generalizable features.`
#
# ---
#
# ### Validation Performance Trend
#
# - Validation accuracy was **extremely low from the start**, dropping from **6.0% (Epoch 1)** to **~1–3%** for most epochs.
# - Validation loss increased continuously from **3.56 → ~10.04**, indicating divergence rather than convergence.
# - Validation precision and recall remained near **random-chance levels (~0.01–0.03)**.
# - No recovery or stabilization in validation metrics was observed throughout training.
#
# __Interpretation:__
# `The model completely failed to generalize to validation data, suggesting a critical training–validation mismatch.`
#
# ---
#
# ### Overfitting Assessment
#
# - Training accuracy approached **100%**, while validation accuracy collapsed to **near-zero**.
# - The training–validation accuracy gap exceeded **95%**, which is a strong indicator of catastrophic overfitting.
# - Increasing validation loss alongside decreasing training loss confirms model divergence.
#
# __Conclusion:__
# `This training run exhibits catastrophic overfitting and invalid generalization.`
#
# ---
#
# ### Optimal Epoch Selection
#
# - No meaningful optimal epoch exists.
# - Validation performance was already unstable from **Epoch 1** and worsened consistently.
# - Early stopping would **not** resolve the underlying issue.
#
# __Recommended Action:__
# `Do not select any epoch from this run for deployment or reporting.`
#
# ---
#
# ### Test Dataset Performance
#
# - **Test Accuracy:** 34.0%
# - **Test Precision:** 34.23%
# - **Test Recall:** 34.0%
# - **Test Loss:** 5.8641
#
# __Interpretation:__
# `Test performance confirms the validation failure, indicating that the model does not generalize beyond the training set.`
#
# ---
#
# ### Diagnostic Implications
#
# - Possible causes include:
#   - Incorrect or inconsistent class labels between training and validation sets
#   - Mismatched class indices or folder structure
#   - Severe class imbalance without correction
#   - Validation data not aligned with the training distribution
#   - Incorrect loss function for the classification setup
#
# __Final Assessment:__
# `This run is not usable for evaluation or deployment and should be treated as a diagnostic failure rather than a performance result.`

# %% [markdown]
# ## `Stage 3 Residual : 01/24/2026`

# %%
Epoch 1/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 87s 2s/step - accuracy: 0.4325 - loss: 1.5318 - precision: 0.4626 - recall: 0.3444 - val_accuracy: 0.7842 - val_loss: 0.6243 - val_precision: 0.8591 - val_recall: 0.6737
Epoch 2/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - accuracy: 0.7369 - loss: 0.6831 - precision: 0.7768 - recall: 0.6744 - val_accuracy: 0.9053 - val_loss: 0.3508 - val_precision: 0.9213 - val_recall: 0.8632
Epoch 3/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.8350 - loss: 0.4563 - precision: 0.8658 - recall: 0.8025 - val_accuracy: 0.9000 - val_loss: 0.2763 - val_precision: 0.9286 - val_recall: 0.8895
Epoch 4/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.8600 - loss: 0.3847 - precision: 0.8804 - recall: 0.8331 - val_accuracy: 0.9158 - val_loss: 0.2266 - val_precision: 0.9341 - val_recall: 0.8947
Epoch 5/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - accuracy: 0.8944 - loss: 0.3101 - precision: 0.9138 - recall: 0.8750 - val_accuracy: 0.9368 - val_loss: 0.1988 - val_precision: 0.9409 - val_recall: 0.9211
Epoch 6/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 67s 1s/step - accuracy: 0.9056 - loss: 0.2684 - precision: 0.9186 - recall: 0.8888 - val_accuracy: 0.9211 - val_loss: 0.1647 - val_precision: 0.9358 - val_recall: 0.9211
Epoch 7/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - accuracy: 0.9062 - loss: 0.2485 - precision: 0.9156 - recall: 0.8950 - val_accuracy: 0.9368 - val_loss: 0.1693 - val_precision: 0.9468 - val_recall: 0.9368
Epoch 8/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.9256 - loss: 0.2067 - precision: 0.9336 - recall: 0.9144 - val_accuracy: 0.9263 - val_loss: 0.1484 - val_precision: 0.9412 - val_recall: 0.9263
Epoch 9/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 60s 1s/step - accuracy: 0.9319 - loss: 0.1943 - precision: 0.9450 - recall: 0.9231 - val_accuracy: 0.9421 - val_loss: 0.1237 - val_precision: 0.9516 - val_recall: 0.9316
Epoch 10/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9350 - loss: 0.1797 - precision: 0.9427 - recall: 0.9262 - val_accuracy: 0.9368 - val_loss: 0.1256 - val_precision: 0.9415 - val_recall: 0.9316
Epoch 11/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.9344 - loss: 0.1825 - precision: 0.9433 - recall: 0.9262 - val_accuracy: 0.9421 - val_loss: 0.1210 - val_precision: 0.9468 - val_recall: 0.9368
Epoch 12/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.9513 - loss: 0.1478 - precision: 0.9581 - recall: 0.9444 - val_accuracy: 0.9579 - val_loss: 0.1110 - val_precision: 0.9628 - val_recall: 0.9526
Epoch 13/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - accuracy: 0.9506 - loss: 0.1362 - precision: 0.9625 - recall: 0.9463 - val_accuracy: 0.9632 - val_loss: 0.1078 - val_precision: 0.9681 - val_recall: 0.9579
Epoch 14/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9463 - loss: 0.1414 - precision: 0.9525 - recall: 0.9400 - val_accuracy: 0.9474 - val_loss: 0.1103 - val_precision: 0.9521 - val_recall: 0.9421
Epoch 15/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9525 - loss: 0.1274 - precision: 0.9570 - recall: 0.9469 - val_accuracy: 0.9474 - val_loss: 0.1155 - val_precision: 0.9471 - val_recall: 0.9421
Epoch 16/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9444 - loss: 0.1245 - precision: 0.9502 - recall: 0.9419 - val_accuracy: 0.9526 - val_loss: 0.0973 - val_precision: 0.9577 - val_recall: 0.9526
Epoch 17/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9531 - loss: 0.1167 - precision: 0.9560 - recall: 0.9500 - val_accuracy: 0.9526 - val_loss: 0.1008 - val_precision: 0.9577 - val_recall: 0.9526
Epoch 18/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9563 - loss: 0.1130 - precision: 0.9591 - recall: 0.9531 - val_accuracy: 0.9474 - val_loss: 0.1045 - val_precision: 0.9474 - val_recall: 0.9474
Epoch 19/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9675 - loss: 0.1012 - precision: 0.9709 - recall: 0.9600 - val_accuracy: 0.9474 - val_loss: 0.0970 - val_precision: 0.9474 - val_recall: 0.9474
Epoch 20/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9600 - loss: 0.1065 - precision: 0.9635 - recall: 0.9569 - val_accuracy: 0.9526 - val_loss: 0.0974 - val_precision: 0.9526 - val_recall: 0.9526
Epoch 21/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9644 - loss: 0.1031 - precision: 0.9667 - recall: 0.9606 - val_accuracy: 0.9632 - val_loss: 0.0914 - val_precision: 0.9632 - val_recall: 0.9632
Epoch 22/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9681 - loss: 0.0959 - precision: 0.9686 - recall: 0.9644 - val_accuracy: 0.9632 - val_loss: 0.0911 - val_precision: 0.9632 - val_recall: 0.9632
Epoch 23/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9700 - loss: 0.0873 - precision: 0.9724 - recall: 0.9681 - val_accuracy: 0.9632 - val_loss: 0.0841 - val_precision: 0.9683 - val_recall: 0.9632
Epoch 24/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.9619 - loss: 0.0950 - precision: 0.9648 - recall: 0.9588 - val_accuracy: 0.9632 - val_loss: 0.0901 - val_precision: 0.9632 - val_recall: 0.9632
Epoch 25/25
50/50 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9631 - loss: 0.0925 - precision: 0.9679 - recall: 0.9613 - val_accuracy: 0.9632 - val_loss: 0.0853 - val_precision: 0.9632 - val_recall: 0.9632

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# > TEST DATASET
#
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step
# - accuracy: 0.9700
# - loss: 0.0817
# - precision: 0.9700
# - recall: 0.9700

# %% [markdown]
# ___Stage 3 (Training Analysis (Binary Classification)___
#
# **Epochs:** 25
#
# ---
#
# ### Training Performance Trend
#
# - Training accuracy increased substantially from **43.3% (Epoch 1)** to **~96–97% (Epochs 19–25)**.
# - Training loss decreased consistently from **1.53 → ~0.09**, indicating stable and effective convergence.
# - Precision and recall improved steadily, reaching **~0.96–0.97** in later epochs.
# - Minor fluctuations after Epoch ~18 suggest saturation rather than instability.
#
# __Interpretation:__
# `The model learned robust and discriminative features with stable convergence throughout training.`
#
# ---
#
# ### Validation Performance Trend
#
# - Validation accuracy increased rapidly from **78.4% (Epoch 1)** to **>93% by Epoch 5**.
# - Validation accuracy peaked and stabilized at **~96.3% (Epochs 13–25)**.
# - Validation loss decreased from **0.624 → ~0.085**, remaining low and stable in later epochs.
# - Validation precision and recall consistently stayed high (**~0.95–0.97**), indicating balanced performance.
#
# __Interpretation:__
# `The model generalized very well to unseen data, with strong and stable validation metrics.`
#
# ---
#
# ### Overfitting Assessment
#
# - Training and validation accuracy remained closely aligned in later epochs.
# - No sustained increase in validation loss was observed.
# - The training–validation accuracy gap remained minimal (**~1–2%**).
#
# __Conclusion:__
# `No significant overfitting is observed; the model demonstrates strong generalization.`
#
# ---
#
# ### Optimal Epoch Selection
#
# - Optimal performance occurs between **Epochs 21–23**:
#   - Validation accuracy stabilizes at **~96.3%**
#   - Validation loss reaches its lowest range (**~0.084–0.091**)
# - Later epochs show no meaningful improvement.
#
# __Recommended Optimal Epoch:__
# `Epoch 21–23, where validation performance is maximized with stable generalization.`
#
# ---
#
# ### Test Dataset Performance
#
# - **Test Accuracy:** 97.0%
# - **Test Precision:** 97.0%
# - **Test Recall:** 97.0%
# - **Test Loss:** 0.0817
#
# __Interpretation:__
# `The test results confirm excellent real-world generalization, with balanced precision and recall and no observable performance degradation.`
#
# ---
#
# __Final Assessment:__
# `This training run demonstrates strong learning behavior, excellent generalization, and is suitable for deployment or formal reporting.`

# %% [markdown]
# ## `Stage 3 Metal : 01/24/2026`

# %%
Epoch 1/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.5025 - loss: 1.2461 - precision: 0.5188 - recall: 0.4600 - val_accuracy: 0.8067 - val_loss: 0.4687 - val_precision: 0.8273 - val_recall: 0.7667
Epoch 2/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.7342 - loss: 0.6017 - precision: 0.7611 - recall: 0.7117 - val_accuracy: 0.8667 - val_loss: 0.3095 - val_precision: 0.9028 - val_recall: 0.8667
Epoch 3/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 38s 1000ms/step - accuracy: 0.8342 - loss: 0.4304 - precision: 0.8423 - recall: 0.8100 - val_accuracy: 0.9200 - val_loss: 0.2411 - val_precision: 0.9310 - val_recall: 0.9000
Epoch 4/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 38s 993ms/step - accuracy: 0.8533 - loss: 0.3610 - precision: 0.8617 - recall: 0.8358 - val_accuracy: 0.9467 - val_loss: 0.2091 - val_precision: 0.9589 - val_recall: 0.9333
Epoch 5/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.8925 - loss: 0.2722 - precision: 0.9057 - recall: 0.8800 - val_accuracy: 0.9600 - val_loss: 0.1837 - val_precision: 0.9660 - val_recall: 0.9467
Epoch 6/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9025 - loss: 0.2578 - precision: 0.9095 - recall: 0.8958 - val_accuracy: 0.9533 - val_loss: 0.1722 - val_precision: 0.9595 - val_recall: 0.9467
Epoch 7/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9217 - loss: 0.2134 - precision: 0.9261 - recall: 0.9192 - val_accuracy: 0.9600 - val_loss: 0.1628 - val_precision: 0.9728 - val_recall: 0.9533
Epoch 8/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9325 - loss: 0.1821 - precision: 0.9360 - recall: 0.9267 - val_accuracy: 0.9600 - val_loss: 0.1545 - val_precision: 0.9728 - val_recall: 0.9533
Epoch 9/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9342 - loss: 0.1856 - precision: 0.9362 - recall: 0.9300 - val_accuracy: 0.9533 - val_loss: 0.1434 - val_precision: 0.9662 - val_recall: 0.9533
Epoch 10/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9308 - loss: 0.1749 - precision: 0.9338 - recall: 0.9292 - val_accuracy: 0.9667 - val_loss: 0.1443 - val_precision: 0.9730 - val_recall: 0.9600
Epoch 11/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9458 - loss: 0.1462 - precision: 0.9489 - recall: 0.9433 - val_accuracy: 0.9600 - val_loss: 0.1384 - val_precision: 0.9728 - val_recall: 0.9533
Epoch 12/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9492 - loss: 0.1393 - precision: 0.9522 - recall: 0.9467 - val_accuracy: 0.9600 - val_loss: 0.1307 - val_precision: 0.9728 - val_recall: 0.9533
Epoch 13/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9592 - loss: 0.1129 - precision: 0.9599 - recall: 0.9583 - val_accuracy: 0.9600 - val_loss: 0.1335 - val_precision: 0.9662 - val_recall: 0.9533
Epoch 14/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9700 - loss: 0.1033 - precision: 0.9724 - recall: 0.9683 - val_accuracy: 0.9600 - val_loss: 0.1318 - val_precision: 0.9664 - val_recall: 0.9600
Epoch 15/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9683 - loss: 0.1000 - precision: 0.9707 - recall: 0.9650 - val_accuracy: 0.9600 - val_loss: 0.1295 - val_precision: 0.9662 - val_recall: 0.9533
Epoch 16/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9617 - loss: 0.1012 - precision: 0.9649 - recall: 0.9608 - val_accuracy: 0.9600 - val_loss: 0.1326 - val_precision: 0.9664 - val_recall: 0.9600
Epoch 17/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 38s 989ms/step - accuracy: 0.9642 - loss: 0.1040 - precision: 0.9641 - recall: 0.9625 - val_accuracy: 0.9667 - val_loss: 0.1321 - val_precision: 0.9664 - val_recall: 0.9600
Epoch 18/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 34s 904ms/step - accuracy: 0.9708 - loss: 0.0921 - precision: 0.9724 - recall: 0.9700 - val_accuracy: 0.9600 - val_loss: 0.1295 - val_precision: 0.9664 - val_recall: 0.9600
Epoch 19/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 34s 908ms/step - accuracy: 0.9692 - loss: 0.0852 - precision: 0.9699 - recall: 0.9683 - val_accuracy: 0.9600 - val_loss: 0.1292 - val_precision: 0.9664 - val_recall: 0.9600
Epoch 20/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 35s 912ms/step - accuracy: 0.9708 - loss: 0.0921 - precision: 0.9724 - recall: 0.9692 - val_accuracy: 0.9600 - val_loss: 0.1252 - val_precision: 0.9600 - val_recall: 0.9600
Epoch 21/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 37s 949ms/step - accuracy: 0.9733 - loss: 0.0729 - precision: 0.9741 - recall: 0.9717 - val_accuracy: 0.9600 - val_loss: 0.1298 - val_precision: 0.9730 - val_recall: 0.9600
Epoch 22/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9817 - loss: 0.0744 - precision: 0.9833 - recall: 0.9817 - val_accuracy: 0.9600 - val_loss: 0.1286 - val_precision: 0.9600 - val_recall: 0.9600
Epoch 23/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9725 - loss: 0.0809 - precision: 0.9749 - recall: 0.9700 - val_accuracy: 0.9600 - val_loss: 0.1280 - val_precision: 0.9600 - val_recall: 0.9600
Epoch 24/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9808 - loss: 0.0679 - precision: 0.9816 - recall: 0.9800 - val_accuracy: 0.9600 - val_loss: 0.1228 - val_precision: 0.9662 - val_recall: 0.9533
Epoch 25/25
38/38 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9775 - loss: 0.0635 - precision: 0.9799 - recall: 0.9758 - val_accuracy: 0.9600 - val_loss: 0.1250 - val_precision: 0.9664 - val_recall: 0.9600

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step
# - accuracy: 0.9933
# - loss: 0.0524
# - precision: 0.9933
# - recall: 0.9867
