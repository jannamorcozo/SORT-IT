# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42
AUTOTUNE = tf.data.AUTOTUNE

DATASET_DIR = "../DATASET/dataset_stage3_paper"
TRAIN_DIR = os.path.join(DATASET_DIR, "train")
VAL_DIR = os.path.join(DATASET_DIR, "val")
TEST_DIR = os.path.join(DATASET_DIR, "test")

# Testing on real-life images (not used for training/validation)
REAL_LIFE_DIR = "../DATASET/dataset_stage3_paper/real_world" 

# Training schedule
EPOCHS_PHASE1 = 5
EPOCHS_PHASE2 = 20
LR_PHASE1 = 1e-3
LR_PHASE2 = 1e-5

# Fine-tuning
N_UNFROZEN = 40  # unfreeze last N layers (BN stays frozen)

tf.random.set_seed(SEED)
np.random.seed(SEED)

# %%
def _random_jpeg_quality(x, min_q=40, max_q=95):
    """Placeholder JPEG compressor (no-op for safety in graph-mode)."""
    return x


def _gaussian_kernel(ksize: int, sigma: float):
    ax = tf.range(-ksize // 2 + 1, ksize // 2 + 1, dtype=tf.float32)
    xx, yy = tf.meshgrid(ax, ax)
    kernel = tf.exp(-(xx**2 + yy**2) / (2.0 * sigma**2))
    kernel = kernel / tf.reduce_sum(kernel)
    kernel = kernel[:, :, tf.newaxis, tf.newaxis]
    return kernel


def _gaussian_blur(x, ksize=5, sigma_min=0.3, sigma_max=1.5):
    sigma = tf.random.uniform([], sigma_min, sigma_max)
    kernel = _gaussian_kernel(ksize, sigma)
    x4 = x[tf.newaxis, ...]
    kernel = tf.tile(kernel, [1, 1, tf.shape(x)[-1], 1])
    x_blur = tf.nn.depthwise_conv2d(x4, kernel, strides=[1, 1, 1, 1], padding="SAME")
    return x_blur[0]


def _add_sensor_noise(x, std_min=0.0, std_max=12.0):
    std = tf.random.uniform([], std_min, std_max)
    noise = tf.random.normal(tf.shape(x), mean=0.0, stddev=std, dtype=tf.float32)
    return tf.clip_by_value(x + noise, 0.0, 255.0)


def _random_crop_resize(x, y, min_scale=0.6, max_scale=1.0):
    h = tf.shape(x)[0]
    w = tf.shape(x)[1]
    scale = tf.random.uniform([], min_scale, max_scale)
    new_h = tf.maximum(tf.cast(tf.cast(h, tf.float32) * scale, tf.int32), 1)
    new_w = tf.maximum(tf.cast(tf.cast(w, tf.float32) * scale, tf.int32), 1)
    crop_size = tf.stack([new_h, new_w, tf.shape(x)[-1]])
    x = tf.image.random_crop(x, size=crop_size, seed=SEED)
    x = tf.image.resize(x, IMG_SIZE, method="bilinear")
    return x, y


# Small tilt augmentation using Keras preprocessing
random_rotation = tf.keras.layers.RandomRotation(factor=20.0 / 360.0, fill_mode="reflect")


def _augment_single_example(x, y):
    """Augment a single image (unbatched)."""
    x, y = _random_crop_resize(x, y)

    # Horizontal flip
    x = tf.image.random_flip_left_right(x, seed=SEED)

    # Random 90° rotations sometimes
    do_rot90 = tf.random.uniform([]) < 0.20
    k = tf.random.uniform([], 0, 4, dtype=tf.int32)
    x = tf.cond(do_rot90, lambda: tf.image.rot90(x, k=k), lambda: x)

    # Small tilt using RandomRotation
    do_tilt = tf.random.uniform([]) < 0.60
    x = tf.cond(
        do_tilt,
        lambda: random_rotation(x[tf.newaxis, ...], training=True)[0],
        lambda: x,
    )

    # Color / lighting tweaks
    x = tf.image.random_brightness(x, max_delta=0.25)
    x = tf.image.random_contrast(x, lower=0.6, upper=1.4)
    x = tf.image.random_saturation(x, lower=0.7, upper=1.3)
    x = tf.image.random_hue(x, max_delta=0.05)

    # Occasional blur / sensor noise
    x = tf.cond(tf.random.uniform([]) < 0.35, lambda: _gaussian_blur(x, ksize=5), lambda: x)
    x = tf.cond(tf.random.uniform([]) < 0.50, lambda: _add_sensor_noise(x), lambda: x)

    # Model preprocessing
    x = preprocess_input(x)
    return x, y


def camera_like_augment(x, y):
    """Apply augmentations to batched or single images."""
    if x.shape.rank == 4:
        x, y = tf.map_fn(
            lambda sample: _augment_single_example(sample[0], sample[1]),
            (x, y),
            fn_output_signature=(tf.float32, tf.float32),
        )
        return x, y

    return _augment_single_example(x, y)


def basic_preprocess(x, y):
    return preprocess_input(x), y

# %%
def camera_like_augment(x, y):
    """Apply augmentations to batched or single images."""
    if x.shape.rank == 4:
        x, y = tf.map_fn(
            lambda sample: _camera_like_augment_single(sample[0], sample[1]),
            (x, y),
            fn_output_signature=(tf.float32, tf.float32),
        )
        return x, y
    
    return _camera_like_augment_single(x, y)


def _camera_like_augment_single(x, y):
    """Augment a single image; input is float32 in [0,255]."""
    x, y = _random_crop_resize(x, y)

    # Flip and orientation
    x = tf.image.random_flip_left_right(x, seed=SEED)
    do_rot90 = tf.random.uniform([]) < 0.20
    k = tf.random.uniform([], 0, 4, dtype=tf.int32)
    x = tf.cond(do_rot90, lambda: tf.image.rot90(x, k=k), lambda: x)

    # Tilt (small rotation)
    do_tilt = tf.random.uniform([]) < 0.60
    x = tf.cond(
        do_tilt,
        lambda: random_rotation(x[tf.newaxis, ...], training=True)[0],
        lambda: x,
    )

    # Color / lighting
    x = tf.image.random_brightness(x, max_delta=0.25)
    x = tf.image.random_contrast(x, lower=0.6, upper=1.4)
    x = tf.image.random_saturation(x, lower=0.7, upper=1.3)
    x = tf.image.random_hue(x, max_delta=0.05)

    # Blur / noise / jpeg
    x = tf.cond(tf.random.uniform([]) < 0.35, lambda: _gaussian_blur(x, ksize=5), lambda: x)
    x = tf.cond(tf.random.uniform([]) < 0.50, lambda: _add_sensor_noise(x), lambda: x)
    x = tf.cond(tf.random.uniform([]) < 0.35, lambda: _random_jpeg_quality(x), lambda: x)

    # Final model preprocessing
    x = preprocess_input(x)
    return x, y


def basic_preprocess(x, y):
    return preprocess_input(x), y

# %%
train_ds = image_dataset_from_directory(
    TRAIN_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="categorical",
    shuffle=True,
    seed=SEED
)

val_ds = image_dataset_from_directory(
    VAL_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="categorical",
    shuffle=False
)

test_ds = image_dataset_from_directory(
    TEST_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="categorical",
    shuffle=False
)

class_names = train_ds.class_names
NUM_CLASSES = len(class_names)
print("Class names:", class_names)
print("NUM_CLASSES:", NUM_CLASSES)

real_life_ds = None
if REAL_LIFE_DIR is not None and os.path.isdir(REAL_LIFE_DIR):
    real_life_ds = image_dataset_from_directory(
        REAL_LIFE_DIR,
        image_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        label_mode="categorical",
        shuffle=False
    )
    print("Real-life class names:", real_life_ds.class_names)
else:
    print("Real-life class names: N/A (REAL_LIFE_DIR not found)")

train_ds = train_ds.map(camera_like_augment, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
val_ds = val_ds.map(basic_preprocess, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
test_ds = test_ds.map(basic_preprocess, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)

if real_life_ds is not None:
    real_life_ds = real_life_ds.map(basic_preprocess, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
# Out:
# Found 2005 files belonging to 5 classes.
# Found 250 files belonging to 5 classes.
# Found 250 files belonging to 5 classes.
# Class names: ['mp', 'occ', 'onp', 'swl', 'ubc']
# NUM_CLASSES: 5
# Found 144 files belonging to 5 classes.
# Real-life class names: ['mp', 'occ', 'onp', 'swl', 'ubc']

# %%
base_model = MobileNetV3Large(
    input_shape=IMG_SIZE + (3,),
    include_top=False,
    weights="imagenet"
)

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation="relu")(x)
x = Dropout(0.5)(x)
output = Dense(NUM_CLASSES, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=output)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 224, 224,  │          0 │ input_layer[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv (Conv2D)       │ (None, 112, 112,  │        432 │ rescaling[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_bn             │ (None, 112, 112,  │         64 │ conv[0][0]        │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 112, 112,  │          0 │ conv_bn[0][0]     │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        144 │ activation[0][0]  │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │         64 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 112, 112,  │          0 │ expanded_conv_de… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │        256 │ re_lu[0][0]       │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_add   │ (None, 112, 112,  │          0 │ activation[0][0], │
# │ (Add)               │ 16)               │            │ expanded_conv_pr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 112, 112,  │      1,024 │ expanded_conv_ad… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 112, 112,  │        256 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 112, 112,  │          0 │ expanded_conv_1_… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 113, 113,  │          0 │ re_lu_1[0][0]     │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 56, 56,    │        576 │ expanded_conv_1_… │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 56, 56,    │        256 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_1_… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 56, 56,    │      1,536 │ re_lu_2[0][0]     │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 56, 56,    │         96 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 56, 56,    │      1,728 │ expanded_conv_1_… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 56, 56,    │        288 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_2_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 56, 56,    │        648 │ re_lu_3[0][0]     │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 56, 56,    │        288 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_2_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 56, 56,    │      1,728 │ re_lu_4[0][0]     │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 56, 56,    │         96 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_add │ (None, 56, 56,    │          0 │ expanded_conv_1_… │
# │ (Add)               │ 24)               │            │ expanded_conv_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 56, 56,    │      1,728 │ expanded_conv_2_… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 56, 56,    │        288 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_3_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 59, 59,    │          0 │ re_lu_5[0][0]     │
# │ (ZeroPadding2D)     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 28, 28,    │      1,800 │ expanded_conv_3_… │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 28, 28,    │        288 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_3_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 72)  │          0 │ re_lu_6[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │      1,752 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │          0 │ expanded_conv_3_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 72)  │      1,800 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1, 1, 72)  │          0 │ expanded_conv_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 1, 1, 72)  │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 1, 1, 72)  │          0 │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 28, 28,    │          0 │ re_lu_6[0][0],    │
# │ (Multiply)          │ 72)               │            │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 28, 28,    │      2,880 │ expanded_conv_3_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 28, 28,    │        160 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 28, 28,    │      4,800 │ expanded_conv_3_… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 28, 28,    │        480 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 28, 28,    │      3,000 │ re_lu_8[0][0]     │
# │ (DepthwiseConv2D)   │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 28, 28,    │        480 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 120) │          0 │ re_lu_9[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 32)  │      3,872 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 32)  │          0 │ expanded_conv_4_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 120) │      3,960 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 1, 1, 120) │          0 │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 1, 1, 120) │          0 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 1, 1, 120) │          0 │ re_lu_10[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 28, 28,    │          0 │ re_lu_9[0][0],    │
# │ (Multiply)          │ 120)              │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 28, 28,    │      4,800 │ expanded_conv_4_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 28, 28,    │        160 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_add │ (None, 28, 28,    │          0 │ expanded_conv_3_… │
# │ (Add)               │ 40)               │            │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 28, 28,    │      4,800 │ expanded_conv_4_… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 28, 28,    │        480 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_5_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 28, 28,    │      3,000 │ re_lu_11[0][0]    │
# │ (DepthwiseConv2D)   │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 28, 28,    │        480 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_5_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 120) │          0 │ re_lu_12[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 32)  │      3,872 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 32)  │          0 │ expanded_conv_5_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 120) │      3,960 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 1, 1, 120) │          0 │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 1, 1, 120) │          0 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 1, 1, 120) │          0 │ re_lu_13[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 28, 28,    │          0 │ re_lu_12[0][0],   │
# │ (Multiply)          │ 120)              │            │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 28, 28,    │      4,800 │ expanded_conv_5_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 28, 28,    │        160 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_add │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │ (Add)               │ 40)               │            │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 28, 28,    │      9,600 │ expanded_conv_5_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 28, 28,    │        960 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 28, 28,    │          0 │ expanded_conv_6_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 29, 29,    │          0 │ activation_1[0][… │
# │ (ZeroPadding2D)     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │      2,160 │ expanded_conv_6_… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │        960 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │     19,200 │ activation_2[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │        320 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │     16,000 │ expanded_conv_6_… │
# │ (Conv2D)            │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │        800 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Activation)        │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │      1,800 │ activation_3[0][… │
# │ (DepthwiseConv2D)   │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │        800 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Activation)        │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │     16,000 │ activation_4[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │        320 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_add │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Add)               │ 80)               │            │ expanded_conv_7_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │     14,720 │ expanded_conv_7_… │
# │ (Conv2D)            │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │        736 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 14, 14,    │      1,656 │ activation_5[0][… │
# │ (DepthwiseConv2D)   │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 14, 14,    │        736 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 14, 14,    │     14,720 │ activation_6[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 14, 14,    │        320 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_add │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Add)               │ 80)               │            │ expanded_conv_8_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 14, 14,    │     14,720 │ expanded_conv_8_… │
# │ (Conv2D)            │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 14, 14,    │        736 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 14, 14,    │          0 │ expanded_conv_9_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 14, 14,    │      1,656 │ activation_7[0][… │
# │ (DepthwiseConv2D)   │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 14, 14,    │        736 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 14, 14,    │          0 │ expanded_conv_9_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 14, 14,    │     14,720 │ activation_8[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 14, 14,    │        320 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_add │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Add)               │ 80)               │            │ expanded_conv_9_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 14, 14,    │     38,400 │ expanded_conv_9_… │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 14, 14,    │      1,920 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 14, 14,    │      4,320 │ activation_9[0][… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 14, 14,    │      1,920 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 480) │          0 │ activation_10[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 120) │     57,720 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 120) │          0 │ expanded_conv_10… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 480) │     58,080 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 1, 1, 480) │          0 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 1, 1, 480) │          0 │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 1, 1, 480) │          0 │ re_lu_14[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 14, 14,    │          0 │ activation_10[0]… │
# │ (Multiply)          │ 480)              │            │ multiply_3[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 14, 14,    │     53,760 │ expanded_conv_10… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 14, 14,    │        448 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_e… │ (None, 14, 14,    │     75,264 │ expanded_conv_10… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_e… │ (None, 14, 14,    │      2,688 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 14, 14,    │          0 │ expanded_conv_11… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_d… │ (None, 14, 14,    │      6,048 │ activation_11[0]… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_d… │ (None, 14, 14,    │      2,688 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 14, 14,    │          0 │ expanded_conv_11… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 672) │          0 │ activation_12[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 168) │    113,064 │ expanded_conv_11… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 168) │          0 │ expanded_conv_11… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 672) │    113,568 │ expanded_conv_11… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 1, 1, 672) │          0 │ expanded_conv_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 1, 1, 672) │          0 │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_4          │ (None, 1, 1, 672) │          0 │ re_lu_15[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 14, 14,    │          0 │ activation_12[0]… │
# │ (Multiply)          │ 672)              │            │ multiply_4[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_p… │ (None, 14, 14,    │     75,264 │ expanded_conv_11… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_p… │ (None, 14, 14,    │        448 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_a… │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Add)               │ 112)              │            │ expanded_conv_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_e… │ (None, 14, 14,    │     75,264 │ expanded_conv_11… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_e… │ (None, 14, 14,    │      2,688 │ expanded_conv_12… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 14, 14,    │          0 │ expanded_conv_12… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 17, 17,    │          0 │ activation_13[0]… │
# │ (ZeroPadding2D)     │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 7, 7, 672) │     16,800 │ expanded_conv_12… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 7, 7, 672) │      2,688 │ expanded_conv_12… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 7, 7, 672) │          0 │ expanded_conv_12… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 672) │          0 │ activation_14[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 168) │    113,064 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 168) │          0 │ expanded_conv_12… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 672) │    113,568 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 1, 1, 672) │          0 │ expanded_conv_12… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 1, 1, 672) │          0 │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_5          │ (None, 1, 1, 672) │          0 │ re_lu_16[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 7, 7, 672) │          0 │ activation_14[0]… │
# │ (Multiply)          │                   │            │ multiply_5[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_p… │ (None, 7, 7, 160) │    107,520 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_12… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_e… │ (None, 7, 7, 960) │    153,600 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_e… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 7, 7, 960) │          0 │ expanded_conv_13… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_d… │ (None, 7, 7, 960) │     24,000 │ activation_15[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_d… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 7, 7, 960) │          0 │ expanded_conv_13… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 960) │          0 │ activation_16[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 240) │    230,640 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 240) │          0 │ expanded_conv_13… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 960) │    231,360 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 1, 1, 960) │          0 │ expanded_conv_13… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 1, 1, 960) │          0 │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_6          │ (None, 1, 1, 960) │          0 │ re_lu_17[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 7, 7, 960) │          0 │ activation_16[0]… │
# │ (Multiply)          │                   │            │ multiply_6[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_p… │ (None, 7, 7, 160) │    153,600 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_a… │ (None, 7, 7, 160) │          0 │ expanded_conv_12… │
# │ (Add)               │                   │            │ expanded_conv_13… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_e… │ (None, 7, 7, 960) │    153,600 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_e… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 7, 7, 960) │          0 │ expanded_conv_14… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_d… │ (None, 7, 7, 960) │     24,000 │ activation_17[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_d… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 7, 7, 960) │          0 │ expanded_conv_14… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 960) │          0 │ activation_18[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 240) │    230,640 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 240) │          0 │ expanded_conv_14… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 960) │    231,360 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 1, 1, 960) │          0 │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 1, 1, 960) │          0 │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 1, 1, 960) │          0 │ re_lu_18[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 7, 7, 960) │          0 │ activation_18[0]… │
# │ (Multiply)          │                   │            │ multiply_7[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_p… │ (None, 7, 7, 160) │    153,600 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_a… │ (None, 7, 7, 160) │          0 │ expanded_conv_13… │
# │ (Add)               │                   │            │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1 (Conv2D)     │ (None, 7, 7, 960) │    153,600 │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1_bn           │ (None, 7, 7, 960) │      3,840 │ conv_1[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 7, 7, 960) │          0 │ conv_1_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 960)       │          0 │ activation_19[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 256)       │    246,016 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 5)         │      1,285 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,243,653 (12.37 MB)
#  Trainable params: 3,219,253 (12.28 MB)
#  Non-trainable params: 24,400 (95.31 KB)

# %%
def compile_model(lr: float):
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
        metrics=[
            "accuracy",
            tf.keras.metrics.TopKCategoricalAccuracy(k=2, name="top2_acc"),
            tf.keras.metrics.TopKCategoricalAccuracy(k=3, name="top3_acc"),

            # One-vs-rest PR-AUC over classes (macro-ish behavior)
            tf.keras.metrics.AUC(name="pr_auc_ovr", curve="PR", multi_label=True, num_labels=NUM_CLASSES),
        ],
    )

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score

class MacroPRCallback(tf.keras.callbacks.Callback):
    def __init__(self, val_ds, num_classes, name_prefix=""):
        super().__init__()
        self.val_ds = val_ds
        self.num_classes = num_classes
        self.name_prefix = name_prefix

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}

        y_true = []
        y_prob = []
        for xb, yb in self.val_ds:
            p = self.model.predict(xb, verbose=0)
            y_prob.append(p)
            y_true.append(np.argmax(yb.numpy(), axis=1))

        y_true = np.concatenate(y_true)
        y_prob = np.concatenate(y_prob, axis=0)
        y_pred = np.argmax(y_prob, axis=1)

        macro_prec = precision_score(y_true, y_pred, average="macro", zero_division=0)
        macro_rec = recall_score(y_true, y_pred, average="macro", zero_division=0)

        logs["precision"] = macro_prec
        logs["recall"] = macro_rec
        # Keras will automatically prefix val_? No—so we store them as val_precision/val_recall:
        logs["val_precision"] = macro_prec
        logs["val_recall"] = macro_rec

        print(f"\n[macro] val_precision={macro_prec:.4f} val_recall={macro_rec:.4f}")

macro_cb = MacroPRCallback(val_ds=val_ds, num_classes=NUM_CLASSES)

# %%
base_model.trainable = False
compile_model(LR_PHASE1)

callbacks_phase1 = [
    tf.keras.callbacks.EarlyStopping(monitor="val_pr_auc_ovr", mode="max", patience=3, restore_best_weights=True),
    macro_cb,
]

history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_PHASE1,
    callbacks=callbacks_phase1
)
# Out:
# Epoch 1/5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 935ms/step - accuracy: 0.5023 - loss: 1.4399 - pr_auc_ovr: 0.5235 - top2_acc: 0.7092 - top3_acc: 0.8294
# [macro] val_precision=0.8391 val_recall=0.8320
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 96s 1s/step - accuracy: 0.6319 - loss: 1.1116 - pr_auc_ovr: 0.6825 - top2_acc: 0.8145 - top3_acc: 0.9062 - val_accuracy: 0.8320 - val_loss: 0.6096 - val_pr_auc_ovr: 0.9240 - val_top2_acc: 0.9720 - val_top3_acc: 0.9920 - precision: 0.8391 - recall: 0.8320 - val_precision: 0.8391 - val_recall: 0.8320
# Epoch 2/5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 689ms/step - accuracy: 0.7824 - loss: 0.7535 - pr_auc_ovr: 0.8618 - top2_acc: 0.9187 - top3_acc: 0.9685
# [macro] val_precision=0.8913 val_recall=0.8880
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 56s 872ms/step - accuracy: 0.7910 - loss: 0.7319 - pr_auc_ovr: 0.8655 - top2_acc: 0.9232 - top3_acc: 0.9706 - val_accuracy: 0.8880 - val_loss: 0.5417 - val_pr_auc_ovr: 0.9480 - val_top2_acc: 0.9680 - val_top3_acc: 0.9920 - precision: 0.8913 - recall: 0.8880 - val_precision: 0.8913 - val_recall: 0.8880
# Epoch 3/5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 673ms/step - accuracy: 0.8084 - loss: 0.6744 - pr_auc_ovr: 0.8909 - top2_acc: 0.9493 - top3_acc: 0.9808
# [macro] val_precision=0.8784 val_recall=0.8720
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 854ms/step - accuracy: 0.8224 - loss: 0.6577 - pr_auc_ovr: 0.8961 - top2_acc: 0.9526 - top3_acc: 0.9820 - val_accuracy: 0.8720 - val_loss: 0.5456 - val_pr_auc_ovr: 0.9447 - val_top2_acc: 0.9680 - val_top3_acc: 0.9960 - precision: 0.8784 - recall: 0.8720 - val_precision: 0.8784 - val_recall: 0.8720
# Epoch 4/5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 682ms/step - accuracy: 0.8522 - loss: 0.6057 - pr_auc_ovr: 0.9226 - top2_acc: 0.9560 - top3_acc: 0.9836
# [macro] val_precision=0.9105 val_recall=0.9040
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 61s 963ms/step - accuracy: 0.8529 - loss: 0.5974 - pr_auc_ovr: 0.9237 - top2_acc: 0.9606 - top3_acc: 0.9860 - val_accuracy: 0.9040 - val_loss: 0.4995 - val_pr_auc_ovr: 0.9590 - val_top2_acc: 0.9760 - val_top3_acc: 0.9960 - precision: 0.9105 - recall: 0.9040 - val_precision: 0.9105 - val_recall: 0.9040
# Epoch 5/5
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - accuracy: 0.8666 - loss: 0.5690 - pr_auc_ovr: 0.9351 - top2_acc: 0.9608 - top3_acc: 0.9899
# [macro] val_precision=0.9137 val_recall=0.9120
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 62s 984ms/step - accuracy: 0.8698 - loss: 0.5631 - pr_auc_ovr: 0.9351 - top2_acc: 0.9666 - top3_acc: 0.9925 - val_accuracy: 0.9120 - val_loss: 0.4885 - val_pr_auc_ovr: 0.9563 - val_top2_acc: 0.9720 - val_top3_acc: 1.0000 - precision: 0.9137 - recall: 0.9120 - val_precision: 0.9137 - val_recall: 0.9120

# %%
base_model.trainable = True

for layer in base_model.layers:
    if isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = False

for layer in base_model.layers[:-N_UNFROZEN]:
    layer.trainable = False

compile_model(LR_PHASE2)

callbacks_phase2 = [
    tf.keras.callbacks.EarlyStopping(monitor="val_pr_auc_ovr", mode="max", patience=5, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_pr_auc_ovr", mode="max", factor=0.5, patience=2, min_lr=1e-7),
    macro_cb,
]

history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_PHASE2,
    callbacks=callbacks_phase2
)
# Out:
# Epoch 1/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 827ms/step - accuracy: 0.8779 - loss: 0.5468 - pr_auc_ovr: 0.9437 - top2_acc: 0.9754 - top3_acc: 0.9910
# [macro] val_precision=0.9004 val_recall=0.8960
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 94s 1s/step - accuracy: 0.8783 - loss: 0.5503 - pr_auc_ovr: 0.9406 - top2_acc: 0.9761 - top3_acc: 0.9915 - val_accuracy: 0.8960 - val_loss: 0.4863 - val_pr_auc_ovr: 0.9619 - val_top2_acc: 0.9760 - val_top3_acc: 0.9960 - learning_rate: 1.0000e-05 - precision: 0.9004 - recall: 0.8960 - val_precision: 0.9004 - val_recall: 0.8960
# Epoch 2/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.8827 - loss: 0.5559 - pr_auc_ovr: 0.9412 - top2_acc: 0.9672 - top3_acc: 0.9913
# [macro] val_precision=0.9082 val_recall=0.9040
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 64s 989ms/step - accuracy: 0.8823 - loss: 0.5423 - pr_auc_ovr: 0.9449 - top2_acc: 0.9696 - top3_acc: 0.9905 - val_accuracy: 0.9040 - val_loss: 0.4840 - val_pr_auc_ovr: 0.9625 - val_top2_acc: 0.9760 - val_top3_acc: 0.9960 - learning_rate: 1.0000e-05 - precision: 0.9082 - recall: 0.9040 - val_precision: 0.9082 - val_recall: 0.9040
# Epoch 3/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 857ms/step - accuracy: 0.8904 - loss: 0.5128 - pr_auc_ovr: 0.9523 - top2_acc: 0.9761 - top3_acc: 0.9936
# [macro] val_precision=0.9114 val_recall=0.9080
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.8918 - loss: 0.5136 - pr_auc_ovr: 0.9521 - top2_acc: 0.9791 - top3_acc: 0.9945 - val_accuracy: 0.9080 - val_loss: 0.4786 - val_pr_auc_ovr: 0.9642 - val_top2_acc: 0.9760 - val_top3_acc: 0.9960 - learning_rate: 1.0000e-05 - precision: 0.9114 - recall: 0.9080 - val_precision: 0.9114 - val_recall: 0.9080
# Epoch 4/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8894 - loss: 0.5174 - pr_auc_ovr: 0.9550 - top2_acc: 0.9783 - top3_acc: 0.9927
# [macro] val_precision=0.9089 val_recall=0.9040
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.8888 - loss: 0.5224 - pr_auc_ovr: 0.9516 - top2_acc: 0.9800 - top3_acc: 0.9950 - val_accuracy: 0.9040 - val_loss: 0.4790 - val_pr_auc_ovr: 0.9651 - val_top2_acc: 0.9760 - val_top3_acc: 0.9960 - learning_rate: 1.0000e-05 - precision: 0.9089 - recall: 0.9040 - val_precision: 0.9089 - val_recall: 0.9040
# Epoch 5/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8834 - loss: 0.5232 - pr_auc_ovr: 0.9518 - top2_acc: 0.9731 - top3_acc: 0.9949
# [macro] val_precision=0.9075 val_recall=0.9040
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.8893 - loss: 0.5144 - pr_auc_ovr: 0.9551 - top2_acc: 0.9741 - top3_acc: 0.9950 - val_accuracy: 0.9040 - val_loss: 0.4758 - val_pr_auc_ovr: 0.9655 - val_top2_acc: 0.9760 - val_top3_acc: 0.9960 - learning_rate: 1.0000e-05 - precision: 0.9075 - recall: 0.9040 - val_precision: 0.9075 - val_recall: 0.9040
# Epoch 6/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8828 - loss: 0.5266 - pr_auc_ovr: 0.9518 - top2_acc: 0.9695 - top3_acc: 0.9937
# [macro] val_precision=0.9153 val_recall=0.9120
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.8928 - loss: 0.5108 - pr_auc_ovr: 0.9573 - top2_acc: 0.9746 - top3_acc: 0.9935 - val_accuracy: 0.9120 - val_loss: 0.4709 - val_pr_auc_ovr: 0.9671 - val_top2_acc: 0.9760 - val_top3_acc: 1.0000 - learning_rate: 1.0000e-05 - precision: 0.9153 - recall: 0.9120 - val_precision: 0.9153 - val_recall: 0.9120
# Epoch 7/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8861 - loss: 0.5152 - pr_auc_ovr: 0.9578 - top2_acc: 0.9727 - top3_acc: 0.9938
# [macro] val_precision=0.9186 val_recall=0.9160
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 138s 2s/step - accuracy: 0.8953 - loss: 0.5065 - pr_auc_ovr: 0.9578 - top2_acc: 0.9756 - top3_acc: 0.9945 - val_accuracy: 0.9160 - val_loss: 0.4673 - val_pr_auc_ovr: 0.9677 - val_top2_acc: 0.9760 - val_top3_acc: 0.9960 - learning_rate: 1.0000e-05 - precision: 0.9186 - recall: 0.9160 - val_precision: 0.9186 - val_recall: 0.9160
# Epoch 8/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8787 - loss: 0.5180 - pr_auc_ovr: 0.9504 - top2_acc: 0.9732 - top3_acc: 0.9964
# [macro] val_precision=0.9152 val_recall=0.9120
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 228s 4s/step - accuracy: 0.8898 - loss: 0.5045 - pr_auc_ovr: 0.9568 - top2_acc: 0.9766 - top3_acc: 0.9950 - val_accuracy: 0.9120 - val_loss: 0.4703 - val_pr_auc_ovr: 0.9667 - val_top2_acc: 0.9760 - val_top3_acc: 1.0000 - learning_rate: 1.0000e-05 - precision: 0.9152 - recall: 0.9120 - val_precision: 0.9152 - val_recall: 0.9120
# Epoch 9/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 891ms/step - accuracy: 0.8942 - loss: 0.4988 - pr_auc_ovr: 0.9620 - top2_acc: 0.9716 - top3_acc: 0.9952
# [macro] val_precision=0.9153 val_recall=0.9120
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.8963 - loss: 0.4916 - pr_auc_ovr: 0.9625 - top2_acc: 0.9796 - top3_acc: 0.9955 - val_accuracy: 0.9120 - val_loss: 0.4655 - val_pr_auc_ovr: 0.9684 - val_top2_acc: 0.9760 - val_top3_acc: 0.9960 - learning_rate: 1.0000e-05 - precision: 0.9153 - recall: 0.9120 - val_precision: 0.9153 - val_recall: 0.9120
# Epoch 10/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 816ms/step - accuracy: 0.8996 - loss: 0.4968 - pr_auc_ovr: 0.9637 - top2_acc: 0.9749 - top3_acc: 0.9938
# [macro] val_precision=0.9153 val_recall=0.9120
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 64s 1s/step - accuracy: 0.8963 - loss: 0.4991 - pr_auc_ovr: 0.9616 - top2_acc: 0.9761 - top3_acc: 0.9955 - val_accuracy: 0.9120 - val_loss: 0.4652 - val_pr_auc_ovr: 0.9681 - val_top2_acc: 0.9760 - val_top3_acc: 1.0000 - learning_rate: 1.0000e-05 - precision: 0.9153 - recall: 0.9120 - val_precision: 0.9153 - val_recall: 0.9120
# Epoch 11/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 794ms/step - accuracy: 0.8920 - loss: 0.4959 - pr_auc_ovr: 0.9643 - top2_acc: 0.9746 - top3_acc: 0.9954
# [macro] val_precision=0.9153 val_recall=0.9120
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 62s 978ms/step - accuracy: 0.8978 - loss: 0.4923 - pr_auc_ovr: 0.9641 - top2_acc: 0.9766 - top3_acc: 0.9950 - val_accuracy: 0.9120 - val_loss: 0.4650 - val_pr_auc_ovr: 0.9683 - val_top2_acc: 0.9720 - val_top3_acc: 0.9960 - learning_rate: 1.0000e-05 - precision: 0.9153 - recall: 0.9120 - val_precision: 0.9153 - val_recall: 0.9120
# Epoch 12/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 900ms/step - accuracy: 0.9002 - loss: 0.4892 - pr_auc_ovr: 0.9642 - top2_acc: 0.9837 - top3_acc: 0.9984
# [macro] val_precision=0.9153 val_recall=0.9120
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 90s 1s/step - accuracy: 0.8963 - loss: 0.4934 - pr_auc_ovr: 0.9607 - top2_acc: 0.9830 - top3_acc: 0.9960 - val_accuracy: 0.9120 - val_loss: 0.4621 - val_pr_auc_ovr: 0.9696 - val_top2_acc: 0.9800 - val_top3_acc: 0.9960 - learning_rate: 5.0000e-06 - precision: 0.9153 - recall: 0.9120 - val_precision: 0.9153 - val_recall: 0.9120
# Epoch 13/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 841ms/step - accuracy: 0.8942 - loss: 0.4975 - pr_auc_ovr: 0.9639 - top2_acc: 0.9694 - top3_acc: 0.9913
# [macro] val_precision=0.9153 val_recall=0.9120
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9062 - loss: 0.4852 - pr_auc_ovr: 0.9664 - top2_acc: 0.9766 - top3_acc: 0.9940 - val_accuracy: 0.9120 - val_loss: 0.4612 - val_pr_auc_ovr: 0.9697 - val_top2_acc: 0.9800 - val_top3_acc: 0.9960 - learning_rate: 5.0000e-06 - precision: 0.9153 - recall: 0.9120 - val_precision: 0.9153 - val_recall: 0.9120
# Epoch 14/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 829ms/step - accuracy: 0.9178 - loss: 0.4609 - pr_auc_ovr: 0.9723 - top2_acc: 0.9848 - top3_acc: 0.9971
# [macro] val_precision=0.9153 val_recall=0.9120
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9107 - loss: 0.4727 - pr_auc_ovr: 0.9676 - top2_acc: 0.9820 - top3_acc: 0.9960 - val_accuracy: 0.9120 - val_loss: 0.4600 - val_pr_auc_ovr: 0.9699 - val_top2_acc: 0.9760 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-06 - precision: 0.9153 - recall: 0.9120 - val_precision: 0.9153 - val_recall: 0.9120
# Epoch 15/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9129 - loss: 0.4693 - pr_auc_ovr: 0.9693 - top2_acc: 0.9874 - top3_acc: 0.9981
# [macro] val_precision=0.9153 val_recall=0.9120
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 63s 984ms/step - accuracy: 0.9147 - loss: 0.4715 - pr_auc_ovr: 0.9691 - top2_acc: 0.9845 - top3_acc: 0.9975 - val_accuracy: 0.9120 - val_loss: 0.4619 - val_pr_auc_ovr: 0.9692 - val_top2_acc: 0.9720 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-06 - precision: 0.9153 - recall: 0.9120 - val_precision: 0.9153 - val_recall: 0.9120
# Epoch 16/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 845ms/step - accuracy: 0.9105 - loss: 0.4681 - pr_auc_ovr: 0.9696 - top2_acc: 0.9850 - top3_acc: 0.9969
# [macro] val_precision=0.9153 val_recall=0.9120
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 0.9172 - loss: 0.4657 - pr_auc_ovr: 0.9704 - top2_acc: 0.9850 - top3_acc: 0.9975 - val_accuracy: 0.9120 - val_loss: 0.4612 - val_pr_auc_ovr: 0.9696 - val_top2_acc: 0.9760 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-06 - precision: 0.9153 - recall: 0.9120 - val_precision: 0.9153 - val_recall: 0.9120
# Epoch 17/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - accuracy: 0.9136 - loss: 0.4724 - pr_auc_ovr: 0.9686 - top2_acc: 0.9863 - top3_acc: 0.9948
# [macro] val_precision=0.9153 val_recall=0.9120
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 63s 990ms/step - accuracy: 0.9097 - loss: 0.4760 - pr_auc_ovr: 0.9665 - top2_acc: 0.9830 - top3_acc: 0.9965 - val_accuracy: 0.9120 - val_loss: 0.4599 - val_pr_auc_ovr: 0.9703 - val_top2_acc: 0.9760 - val_top3_acc: 1.0000 - learning_rate: 2.5000e-06 - precision: 0.9153 - recall: 0.9120 - val_precision: 0.9153 - val_recall: 0.9120
# Epoch 18/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 889ms/step - accuracy: 0.9178 - loss: 0.4810 - pr_auc_ovr: 0.9641 - top2_acc: 0.9815 - top3_acc: 0.9920
# [macro] val_precision=0.9153 val_recall=0.9120
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9157 - loss: 0.4750 - pr_auc_ovr: 0.9655 - top2_acc: 0.9825 - top3_acc: 0.9940 - val_accuracy: 0.9120 - val_loss: 0.4615 - val_pr_auc_ovr: 0.9696 - val_top2_acc: 0.9760 - val_top3_acc: 1.0000 - learning_rate: 2.5000e-06 - precision: 0.9153 - recall: 0.9120 - val_precision: 0.9153 - val_recall: 0.9120
# Epoch 19/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 788ms/step - accuracy: 0.9227 - loss: 0.4556 - pr_auc_ovr: 0.9767 - top2_acc: 0.9853 - top3_acc: 0.9971
# [macro] val_precision=0.9153 val_recall=0.9120
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 62s 981ms/step - accuracy: 0.9202 - loss: 0.4583 - pr_auc_ovr: 0.9741 - top2_acc: 0.9850 - top3_acc: 0.9970 - val_accuracy: 0.9120 - val_loss: 0.4611 - val_pr_auc_ovr: 0.9697 - val_top2_acc: 0.9760 - val_top3_acc: 1.0000 - learning_rate: 2.5000e-06 - precision: 0.9153 - recall: 0.9120 - val_precision: 0.9153 - val_recall: 0.9120
# Epoch 20/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 844ms/step - accuracy: 0.9107 - loss: 0.4758 - pr_auc_ovr: 0.9697 - top2_acc: 0.9790 - top3_acc: 0.9885
# [macro] val_precision=0.9153 val_recall=0.9120
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9147 - loss: 0.4648 - pr_auc_ovr: 0.9708 - top2_acc: 0.9865 - top3_acc: 0.9935 - val_accuracy: 0.9120 - val_loss: 0.4606 - val_pr_auc_ovr: 0.9698 - val_top2_acc: 0.9760 - val_top3_acc: 1.0000 - learning_rate: 1.2500e-06 - precision: 0.9153 - recall: 0.9120 - val_precision: 0.9153 - val_recall: 0.9120

# %%
def merge_histories(h1, h2):
    merged = {}
    keys = set(h1.history.keys()) | set(h2.history.keys())
    for k in keys:
        merged[k] = list(h1.history.get(k, [])) + list(h2.history.get(k, []))
    return merged

merged = merge_histories(history1, history2)

plt.figure(figsize=(12, 7))

plt.subplot(2, 2, 1)
plt.plot(merged.get("accuracy", []), label="Train Accuracy")
plt.plot(merged.get("val_accuracy", []), label="Val Accuracy")
plt.legend(); plt.title("Accuracy")

plt.subplot(2, 2, 2)
plt.plot(merged.get("loss", []), label="Train Loss")
plt.plot(merged.get("val_loss", []), label="Val Loss")
plt.legend(); plt.title("Loss")

plt.subplot(2, 2, 3)
plt.plot(merged.get("precision", []), label="Train Precision (macro)")
plt.plot(merged.get("val_precision", []), label="Val Precision (macro)")
plt.legend(); plt.title("Precision (macro)")

plt.subplot(2, 2, 4)
plt.plot(merged.get("recall", []), label="Train Recall (macro)")
plt.plot(merged.get("val_recall", []), label="Val Recall (macro)")
plt.legend(); plt.title("Recall (macro)")

plt.tight_layout()
plt.show()

# %%
def report_and_cm_multiclass(ds, class_names, title=""):
    y_true = []
    y_probs = []

    for xb, yb in ds:
        probs = model.predict(xb, verbose=0)
        y_probs.append(probs)
        y_true.append(np.argmax(yb.numpy(), axis=1))

    y_probs = np.concatenate(y_probs, axis=0)
    y_true = np.concatenate(y_true, axis=0)
    y_pred = np.argmax(y_probs, axis=1)

    print("\n" + title)
    print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(7, 6))
    plt.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
    plt.title(f"Confusion Matrix - {title}")
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45, ha="right")
    plt.yticks(tick_marks, class_names)

    thresh = cm.max() / 2 if cm.max() > 0 else 0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, cm[i, j],
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")

    plt.ylabel("True label")
    plt.xlabel("Predicted label")
    plt.tight_layout()
    plt.show()

# TEST confusion matrix
report_and_cm_multiclass(test_ds, class_names, title="TEST")

# REAL-LIFE confusion matrix (if you have it)
if real_life_ds is not None:
    report_and_cm_multiclass(real_life_ds, class_names, title="REAL-LIFE")
# Out:
# TEST
#               precision    recall  f1-score   support
#
#           mp     0.7018    0.8000    0.7477        50
#          occ     0.9792    0.9400    0.9592        50
#          onp     0.9750    0.7800    0.8667        50
#          swl     0.8000    0.8800    0.8381        50
#          ubc     0.9400    0.9400    0.9400        50
#
#     accuracy                         0.8680       250
#    macro avg     0.8792    0.8680    0.8703       250
# weighted avg     0.8792    0.8680    0.8703       250
# REAL-LIFE
#               precision    recall  f1-score   support
#
#           mp     0.4074    0.3056    0.3492        36
#          occ     0.6786    0.6786    0.6786        28
#          onp     0.7308    0.9500    0.8261        20
#          swl     0.7097    0.7333    0.7213        30
#          ubc     0.7188    0.7667    0.7419        30
#
#     accuracy                         0.6528       144
#    macro avg     0.6490    0.6868    0.6634       144
# weighted avg     0.6329    0.6528    0.6388       144

# %%
print("\nDataset test evaluation:")
model.evaluate(test_ds, verbose=2)

if real_life_ds is not None:
    print("\nReal-life evaluation:")
    model.evaluate(real_life_ds, verbose=2)
# Out:
# Dataset test evaluation:
# 8/8 - 8s - 963ms/step - accuracy: 0.8680 - loss: 0.5491 - pr_auc_ovr: 0.9442 - top2_acc: 0.9800 - top3_acc: 0.9880
#
# Real-life evaluation:
# 5/5 - 6s - 1s/step - accuracy: 0.6528 - loss: 0.9619 - pr_auc_ovr: 0.7570 - top2_acc: 0.8681 - top3_acc: 0.9792

# %%
def collect_probs_and_labels(ds):
    y_true = []
    y_prob = []
    for xb, yb in ds:
        p = model.predict(xb, verbose=0)  # (B, C)
        y_prob.append(p)
        y_true.append(yb.numpy())
    y_true = np.concatenate(y_true, axis=0)  # one-hot
    y_prob = np.concatenate(y_prob, axis=0)
    y_true_idx = np.argmax(y_true, axis=1)
    return y_true, y_true_idx, y_prob

cal_ds = real_life_ds if real_life_ds is not None else test_ds  # fallback, but real-life is strongly preferred
y_true_oh, y_true_idx, y_prob = collect_probs_and_labels(cal_ds)

print("Calibration dataset size:", len(y_true_idx))
# Out:
# Calibration dataset size: 144

# %%
def calibrate_uncertainty_thresholds(
    y_true_idx,
    y_prob,
    num_classes,
    t_grid=np.linspace(0.40, 0.90, 11),
    margin_grid=np.linspace(0.00, 0.30, 7),
    min_recall_per_class=0.70,   # increase as you collect more real-life images
):
    # Per-class threshold uses same t for all classes initially
    best = None

    p_sorted = np.sort(y_prob, axis=1)
    p1 = p_sorted[:, -1]
    p2 = p_sorted[:, -2]
    pred = np.argmax(y_prob, axis=1)

    for t in t_grid:
        for m in margin_grid:
            accept = (p1 >= t) & ((p1 - p2) >= m)
            coverage = float(np.mean(accept))

            # compute per-class recall among samples of that true class:
            ok = True
            recalls = []
            for c in range(num_classes):
                mask = (y_true_idx == c)
                if not np.any(mask):
                    # no samples of this class in calibration set -> can't constrain it
                    recalls.append(np.nan)
                    continue
                recall_c = float(np.mean((pred[mask] == c) & accept[mask]))
                recalls.append(recall_c)
                if recall_c < min_recall_per_class:
                    ok = False
                    break
            if not ok:
                continue

            candidate = {"t": float(t), "margin": float(m), "coverage": coverage, "recalls": recalls}
            if best is None or candidate["coverage"] > best["coverage"]:
                best = candidate

    return best

best_u = calibrate_uncertainty_thresholds(
    y_true_idx=y_true_idx,
    y_prob=y_prob,
    num_classes=NUM_CLASSES,
    min_recall_per_class=0.70
)

if best_u is None:
    print("No thresholds met constraints. Relax min_recall_per_class (e.g., 0.6) or collect more real-life images.")
else:
    print("Chosen uncertainty params:")
    print("  accept if max_prob >= t AND (p1 - p2) >= margin")
    print(f"  t = {best_u['t']:.2f}")
    print(f"  margin = {best_u['margin']:.2f}")
    print(f"  coverage = {best_u['coverage']:.3f}")
    for i, r in enumerate(best_u["recalls"]):
        print(f"  recall[{class_names[i]}] = {r}")
# Out:
# No thresholds met constraints. Relax min_recall_per_class (e.g., 0.6) or collect more real-life images.

# %%
def apply_uncertainty_policy(y_prob, t, margin):
    p_sorted = np.sort(y_prob, axis=1)
    p1 = p_sorted[:, -1]
    p2 = p_sorted[:, -2]
    pred = np.argmax(y_prob, axis=1)
    accept = (p1 >= t) & ((p1 - p2) >= margin)
    pred_or_uncertain = pred.copy()
    pred_or_uncertain[~accept] = -1
    return pred_or_uncertain, accept

if best_u is not None:
    pred_u, accept = apply_uncertainty_policy(y_prob, best_u["t"], best_u["margin"])
    print("Uncertain rate:", float(np.mean(~accept)))

    # confusion matrix on accepted only
    accepted_idx = np.where(accept)[0]
    if len(accepted_idx) > 0:
        y_true_acc = y_true_idx[accepted_idx]
        y_pred_acc = pred_u[accepted_idx]

        cm = tf.math.confusion_matrix(y_true_acc, y_pred_acc, num_classes=NUM_CLASSES).numpy()
        print("Confusion matrix (accepted samples only):")
        print(cm)
    else:
        print("No accepted samples under current thresholds.")

# %%
OUT_DIR = "./enhanced-model"
os.makedirs(OUT_DIR, exist_ok=True)

tflite_path = os.path.join(OUT_DIR, "stage3_paper_model.tflite")
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open(tflite_path, "wb") as f:
    f.write(tflite_model)
print("Saved TFLite model to:", tflite_path)

if best_u is not None:
    np.savez(
        os.path.join(OUT_DIR, "paper_uncertainty_params.npz"),
        t=best_u["t"],
        margin=best_u["margin"],
        class_names=np.array(class_names, dtype=object),
    )
    print("Saved uncertainty params.")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\VIRGIL~1\AppData\Local\Temp\tmpdtmzip18\assets
# INFO:tensorflow:Assets written to: C:\Users\VIRGIL~1\AppData\Local\Temp\tmpdtmzip18\assets
# Saved artifact at 'C:\Users\VIRGIL~1\AppData\Local\Temp\tmpdtmzip18'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   2989042299856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989044306640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989044312096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989044303472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989044310336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989044305584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042089680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042075072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042078592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042087568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042085456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042088800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042085632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042076128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042073840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989043005952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989043004544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042997328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042996448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989043003136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989043003312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989040211520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042992752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989043001376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989040220848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989040214160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042586320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989041810624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989041801296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042588784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042594592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042582976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042585792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042589488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042594944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989043916944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042500880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042502992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042509504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042501584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042513200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042508800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042506688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042502640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042816224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042820800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042811472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042822912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042825904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042819392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042824320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042896208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042907472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042903072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042901136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042902368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042901488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042899552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042906768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042897968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042341968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042344256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042337216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042343376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042345840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042348304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042350592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042344080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042349712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989042350944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989043047184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989043049648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989043046480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989043043136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989043054400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989043055104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989043054752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061064128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061069760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061072576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061074864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061070816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061073632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061078208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061130896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061128432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061128256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061131072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061134592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061137408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061139696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061135648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061138464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061139520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061230432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061229376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061230784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061235712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061238528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061240816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061236768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061239584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061240640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061312000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061314288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061310240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061313056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061318512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061321328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061323616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061319568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061322384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061323440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061411184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061413472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061409424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061412240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061414704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061417520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061419808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061415760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061418576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061419632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061508608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061509664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061506144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061508784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061512304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061515120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061517408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061513360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061516176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061520752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061573440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061570976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061570800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061573616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061577136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061579952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061582240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061578192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061581008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061585584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061671040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061671568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061671392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061671216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061674736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061677552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061679840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061675792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061678608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061683184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061768640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061767408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061682480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061768816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061772336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061775152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061777440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061773392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061776208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061780784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061779552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061781840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061783072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061865888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061869936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061872752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061875040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061870992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061873808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061879792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061880496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061880144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061981104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061987440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061990256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061992544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061988496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061991312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061994480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066257856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066256624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989061993776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066258032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066261552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066264368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066266656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066262608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066265424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066271408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066272112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066271760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066356336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066362672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066365488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066367776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066363728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066366544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066367600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066440192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066441248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066437728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066440368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066445472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066448288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066450576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066446528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066449344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066450400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066536736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066540256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066541664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066546592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066546064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066547648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066548352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066550288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066651424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066654240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066656528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066652480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066655296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066659168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066661984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066664272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066660224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066663040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066664096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066750432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066753952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066755360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066760288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066759760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066762048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066763456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066846272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066850144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066852960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066855248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066851200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066854016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066857888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066857360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066858944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066859648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066861584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066932768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066933472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066936288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066937696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989066943328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989067061552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989067060848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989067062080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989067061728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989067065248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989067068064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989067070352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989067066304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989067069120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989067068592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989082464272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989082466560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2989082467264: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved TFLite model to: ./enhanced-model\stage3_paper_model.tflite
