# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
SEED = 42
AUTOTUNE = tf.data.AUTOTUNE

DATASET_DIR = "../DATASET/dataset_stage3_metal"
TRAIN_DIR = os.path.join(DATASET_DIR, "train")
VAL_DIR = os.path.join(DATASET_DIR, "val")
TEST_DIR = os.path.join(DATASET_DIR, "test")

# Testing on real-life images (not used for training/validation)
REAL_LIFE_DIR = "../DATASET/dataset_stage3_metal/real_world" 

# Training schedule
EPOCHS_PHASE1 = 5
EPOCHS_PHASE2 = 20
LR_PHASE1 = 1e-3
LR_PHASE2 = 1e-5

# Fine-tuning
N_UNFROZEN = 40  # unfreeze last N layers (BN stays frozen)

tf.random.set_seed(SEED)
np.random.seed(SEED)

# %%
def _random_jpeg_quality(x, min_q=40, max_q=95):
    """Placeholder JPEG compressor (no-op for stable graph-mode)."""
    return x


def _gaussian_kernel(ksize: int, sigma: float):
    ax = tf.range(-ksize // 2 + 1, ksize // 2 + 1, dtype=tf.float32)
    xx, yy = tf.meshgrid(ax, ax)
    kernel = tf.exp(-(xx**2 + yy**2) / (2.0 * sigma**2))
    kernel = kernel / tf.reduce_sum(kernel)
    kernel = kernel[:, :, tf.newaxis, tf.newaxis]
    return kernel


def _gaussian_blur(x, ksize=5, sigma_min=0.3, sigma_max=1.5):
    sigma = tf.random.uniform([], sigma_min, sigma_max)
    kernel = _gaussian_kernel(ksize, sigma)
    x4 = x[tf.newaxis, ...]
    kernel = tf.tile(kernel, [1, 1, tf.shape(x)[-1], 1])
    x_blur = tf.nn.depthwise_conv2d(x4, kernel, strides=[1, 1, 1, 1], padding="SAME")
    return x_blur[0]


def _add_sensor_noise(x, std_min=0.0, std_max=12.0):
    std = tf.random.uniform([], std_min, std_max)
    noise = tf.random.normal(tf.shape(x), mean=0.0, stddev=std, dtype=tf.float32)
    return tf.clip_by_value(x + noise, 0.0, 255.0)


def _random_crop_resize(x, y, min_scale=0.6, max_scale=1.0):
    h = tf.shape(x)[0]
    w = tf.shape(x)[1]
    scale = tf.random.uniform([], min_scale, max_scale)
    new_h = tf.maximum(tf.cast(tf.cast(h, tf.float32) * scale, tf.int32), 1)
    new_w = tf.maximum(tf.cast(tf.cast(w, tf.float32) * scale, tf.int32), 1)
    crop_size = tf.stack([new_h, new_w, tf.shape(x)[-1]])
    x = tf.image.random_crop(x, size=crop_size, seed=SEED)
    x = tf.image.resize(x, IMG_SIZE, method="bilinear")
    return x, y


# Small tilt augmentation using Keras preprocessing
random_rotation = tf.keras.layers.RandomRotation(factor=20.0 / 360.0, fill_mode="reflect")


def _augment_single_example(x, y):
    """Augment a single image (unbatched)."""
    x, y = _random_crop_resize(x, y)

    # Horizontal flip
    x = tf.image.random_flip_left_right(x, seed=SEED)

    # Random 90° rotations sometimes
    do_rot90 = tf.random.uniform([]) < 0.20
    k = tf.random.uniform([], 0, 4, dtype=tf.int32)
    x = tf.cond(do_rot90, lambda: tf.image.rot90(x, k=k), lambda: x)

    # Small tilt using RandomRotation
    do_tilt = tf.random.uniform([]) < 0.60
    x = tf.cond(
        do_tilt,
        lambda: random_rotation(x[tf.newaxis, ...], training=True)[0],
        lambda: x,
    )

    # Color / lighting tweaks
    x = tf.image.random_brightness(x, max_delta=0.25)
    x = tf.image.random_contrast(x, lower=0.6, upper=1.4)
    x = tf.image.random_saturation(x, lower=0.7, upper=1.3)
    x = tf.image.random_hue(x, max_delta=0.05)

    # Occasional blur / sensor noise
    x = tf.cond(tf.random.uniform([]) < 0.35, lambda: _gaussian_blur(x, ksize=5), lambda: x)
    x = tf.cond(tf.random.uniform([]) < 0.50, lambda: _add_sensor_noise(x), lambda: x)

    # Model preprocessing
    x = preprocess_input(x)
    return x, y


def camera_like_augment(x, y):
    """Apply augmentations to batched or single images."""
    # image_dataset_from_directory yields batched tensors (B,H,W,C)
    if x.shape.rank == 4:
        x, y = tf.map_fn(
            lambda sample: _augment_single_example(sample[0], sample[1]),
            (x, y),
            fn_output_signature=(tf.float32, tf.float32),
        )
        return x, y

    return _augment_single_example(x, y)


def basic_preprocess(x, y):
    return preprocess_input(x), y

# %%
def camera_like_augment(x, y):
    """Apply augmentations to batched or single images."""
    if x.shape.rank == 4:
        x, y = tf.map_fn(
            lambda sample: _camera_like_augment_single(sample[0], sample[1]),
            (x, y),
            fn_output_signature=(tf.float32, tf.float32),
        )
        return x, y
    
    return _camera_like_augment_single(x, y)


def _camera_like_augment_single(x, y):
    """Augment a single image; input is float32 in [0,255]."""
    x, y = _random_crop_resize(x, y)

    # Flip and orientation
    x = tf.image.random_flip_left_right(x, seed=SEED)
    do_rot90 = tf.random.uniform([]) < 0.20
    k = tf.random.uniform([], 0, 4, dtype=tf.int32)
    x = tf.cond(do_rot90, lambda: tf.image.rot90(x, k=k), lambda: x)

    # Tilt (small rotation)
    do_tilt = tf.random.uniform([]) < 0.60
    x = tf.cond(
        do_tilt,
        lambda: random_rotation(x[tf.newaxis, ...], training=True)[0],
        lambda: x,
    )

    # Color / lighting
    x = tf.image.random_brightness(x, max_delta=0.25)
    x = tf.image.random_contrast(x, lower=0.6, upper=1.4)
    x = tf.image.random_saturation(x, lower=0.7, upper=1.3)
    x = tf.image.random_hue(x, max_delta=0.05)

    # Blur / noise / jpeg
    x = tf.cond(tf.random.uniform([]) < 0.35, lambda: _gaussian_blur(x, ksize=5), lambda: x)
    x = tf.cond(tf.random.uniform([]) < 0.50, lambda: _add_sensor_noise(x), lambda: x)
    x = tf.cond(tf.random.uniform([]) < 0.35, lambda: _random_jpeg_quality(x), lambda: x)

    # Final model preprocessing
    x = preprocess_input(x)
    return x, y


def basic_preprocess(x, y):
    return preprocess_input(x), y

# %%
train_ds = image_dataset_from_directory(
    TRAIN_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="categorical",
    shuffle=True,
    seed=SEED
)

val_ds = image_dataset_from_directory(
    VAL_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="categorical",
    shuffle=False
)

test_ds = image_dataset_from_directory(
    TEST_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode="categorical",
    shuffle=False
)

class_names = train_ds.class_names
NUM_CLASSES = len(class_names)
print("Class names:", class_names)
print("NUM_CLASSES:", NUM_CLASSES)

real_life_ds = None
if REAL_LIFE_DIR is not None and os.path.isdir(REAL_LIFE_DIR):
    real_life_ds = image_dataset_from_directory(
        REAL_LIFE_DIR,
        image_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        label_mode="categorical",
        shuffle=False
    )
    print("Real-life class names:", real_life_ds.class_names)
else:
    print("Real-life class names: N/A (REAL_LIFE_DIR not found)")

train_ds = train_ds.map(camera_like_augment, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
val_ds = val_ds.map(basic_preprocess, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
test_ds = test_ds.map(basic_preprocess, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)

if real_life_ds is not None:
    real_life_ds = real_life_ds.map(basic_preprocess, num_parallel_calls=AUTOTUNE).prefetch(AUTOTUNE)
# Out:
# Found 1340 files belonging to 3 classes.
# Found 168 files belonging to 3 classes.
# Found 168 files belonging to 3 classes.
# Class names: ['aluminum_tin', 'copper', 'steel']
# NUM_CLASSES: 3
# Found 96 files belonging to 3 classes.
# Real-life class names: ['aluminum_tin', 'copper', 'steel']

# %%
base_model = MobileNetV3Large(
    input_shape=IMG_SIZE + (3,),
    include_top=False,
    weights="imagenet"
)

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation="relu")(x)
x = Dropout(0.5)(x)
output = Dense(NUM_CLASSES, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=output)
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_1         │ (None, 224, 224,  │          0 │ input_layer_1[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv (Conv2D)       │ (None, 112, 112,  │        432 │ rescaling_1[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_bn             │ (None, 112, 112,  │         64 │ conv[0][0]        │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 112, 112,  │          0 │ conv_bn[0][0]     │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        144 │ activation_20[0]… │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │         64 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_19 (ReLU)     │ (None, 112, 112,  │          0 │ expanded_conv_de… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │        256 │ re_lu_19[0][0]    │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_add   │ (None, 112, 112,  │          0 │ activation_20[0]… │
# │ (Add)               │ 16)               │            │ expanded_conv_pr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 112, 112,  │      1,024 │ expanded_conv_ad… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 112, 112,  │        256 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_20 (ReLU)     │ (None, 112, 112,  │          0 │ expanded_conv_1_… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 113, 113,  │          0 │ re_lu_20[0][0]    │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 56, 56,    │        576 │ expanded_conv_1_… │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 56, 56,    │        256 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_21 (ReLU)     │ (None, 56, 56,    │          0 │ expanded_conv_1_… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 56, 56,    │      1,536 │ re_lu_21[0][0]    │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 56, 56,    │         96 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 56, 56,    │      1,728 │ expanded_conv_1_… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 56, 56,    │        288 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_22 (ReLU)     │ (None, 56, 56,    │          0 │ expanded_conv_2_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 56, 56,    │        648 │ re_lu_22[0][0]    │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 56, 56,    │        288 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_23 (ReLU)     │ (None, 56, 56,    │          0 │ expanded_conv_2_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 56, 56,    │      1,728 │ re_lu_23[0][0]    │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 56, 56,    │         96 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_add │ (None, 56, 56,    │          0 │ expanded_conv_1_… │
# │ (Add)               │ 24)               │            │ expanded_conv_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 56, 56,    │      1,728 │ expanded_conv_2_… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 56, 56,    │        288 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_24 (ReLU)     │ (None, 56, 56,    │          0 │ expanded_conv_3_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 59, 59,    │          0 │ re_lu_24[0][0]    │
# │ (ZeroPadding2D)     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 28, 28,    │      1,800 │ expanded_conv_3_… │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 28, 28,    │        288 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_25 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_3_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 72)  │          0 │ re_lu_25[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │      1,752 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │          0 │ expanded_conv_3_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 72)  │      1,800 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 1, 1, 72)  │          0 │ expanded_conv_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_26 (ReLU)     │ (None, 1, 1, 72)  │          0 │ add_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_8          │ (None, 1, 1, 72)  │          0 │ re_lu_26[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 28, 28,    │          0 │ re_lu_25[0][0],   │
# │ (Multiply)          │ 72)               │            │ multiply_8[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 28, 28,    │      2,880 │ expanded_conv_3_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 28, 28,    │        160 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 28, 28,    │      4,800 │ expanded_conv_3_… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 28, 28,    │        480 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_27 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 28, 28,    │      3,000 │ re_lu_27[0][0]    │
# │ (DepthwiseConv2D)   │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 28, 28,    │        480 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_28 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 120) │          0 │ re_lu_28[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 32)  │      3,872 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 32)  │          0 │ expanded_conv_4_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 120) │      3,960 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 1, 1, 120) │          0 │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_29 (ReLU)     │ (None, 1, 1, 120) │          0 │ add_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_9          │ (None, 1, 1, 120) │          0 │ re_lu_29[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 28, 28,    │          0 │ re_lu_28[0][0],   │
# │ (Multiply)          │ 120)              │            │ multiply_9[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 28, 28,    │      4,800 │ expanded_conv_4_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 28, 28,    │        160 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_add │ (None, 28, 28,    │          0 │ expanded_conv_3_… │
# │ (Add)               │ 40)               │            │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 28, 28,    │      4,800 │ expanded_conv_4_… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 28, 28,    │        480 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_30 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_5_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 28, 28,    │      3,000 │ re_lu_30[0][0]    │
# │ (DepthwiseConv2D)   │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 28, 28,    │        480 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_31 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_5_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 120) │          0 │ re_lu_31[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 32)  │      3,872 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 32)  │          0 │ expanded_conv_5_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 120) │      3,960 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 1, 1, 120) │          0 │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_32 (ReLU)     │ (None, 1, 1, 120) │          0 │ add_10[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_10         │ (None, 1, 1, 120) │          0 │ re_lu_32[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 28, 28,    │          0 │ re_lu_31[0][0],   │
# │ (Multiply)          │ 120)              │            │ multiply_10[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 28, 28,    │      4,800 │ expanded_conv_5_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 28, 28,    │        160 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_add │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │ (Add)               │ 40)               │            │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 28, 28,    │      9,600 │ expanded_conv_5_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 28, 28,    │        960 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 28, 28,    │          0 │ expanded_conv_6_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 29, 29,    │          0 │ activation_21[0]… │
# │ (ZeroPadding2D)     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │      2,160 │ expanded_conv_6_… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │        960 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │     19,200 │ activation_22[0]… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │        320 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │     16,000 │ expanded_conv_6_… │
# │ (Conv2D)            │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │        800 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Activation)        │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │      1,800 │ activation_23[0]… │
# │ (DepthwiseConv2D)   │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │        800 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Activation)        │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │     16,000 │ activation_24[0]… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │        320 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_add │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Add)               │ 80)               │            │ expanded_conv_7_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │     14,720 │ expanded_conv_7_… │
# │ (Conv2D)            │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │        736 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 14, 14,    │      1,656 │ activation_25[0]… │
# │ (DepthwiseConv2D)   │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 14, 14,    │        736 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 14, 14,    │     14,720 │ activation_26[0]… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 14, 14,    │        320 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_add │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Add)               │ 80)               │            │ expanded_conv_8_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 14, 14,    │     14,720 │ expanded_conv_8_… │
# │ (Conv2D)            │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 14, 14,    │        736 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 14, 14,    │          0 │ expanded_conv_9_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 14, 14,    │      1,656 │ activation_27[0]… │
# │ (DepthwiseConv2D)   │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 14, 14,    │        736 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 14, 14,    │          0 │ expanded_conv_9_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 14, 14,    │     14,720 │ activation_28[0]… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 14, 14,    │        320 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_add │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Add)               │ 80)               │            │ expanded_conv_9_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 14, 14,    │     38,400 │ expanded_conv_9_… │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 14, 14,    │      1,920 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 14, 14,    │      4,320 │ activation_29[0]… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 14, 14,    │      1,920 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 480) │          0 │ activation_30[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 120) │     57,720 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 120) │          0 │ expanded_conv_10… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 480) │     58,080 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 1, 1, 480) │          0 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_33 (ReLU)     │ (None, 1, 1, 480) │          0 │ add_11[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_11         │ (None, 1, 1, 480) │          0 │ re_lu_33[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 14, 14,    │          0 │ activation_30[0]… │
# │ (Multiply)          │ 480)              │            │ multiply_11[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 14, 14,    │     53,760 │ expanded_conv_10… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 14, 14,    │        448 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_e… │ (None, 14, 14,    │     75,264 │ expanded_conv_10… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_e… │ (None, 14, 14,    │      2,688 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 14, 14,    │          0 │ expanded_conv_11… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_d… │ (None, 14, 14,    │      6,048 │ activation_31[0]… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_d… │ (None, 14, 14,    │      2,688 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 14, 14,    │          0 │ expanded_conv_11… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 672) │          0 │ activation_32[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 168) │    113,064 │ expanded_conv_11… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 168) │          0 │ expanded_conv_11… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 672) │    113,568 │ expanded_conv_11… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 1, 1, 672) │          0 │ expanded_conv_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_34 (ReLU)     │ (None, 1, 1, 672) │          0 │ add_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_12         │ (None, 1, 1, 672) │          0 │ re_lu_34[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 14, 14,    │          0 │ activation_32[0]… │
# │ (Multiply)          │ 672)              │            │ multiply_12[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_p… │ (None, 14, 14,    │     75,264 │ expanded_conv_11… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_p… │ (None, 14, 14,    │        448 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_a… │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Add)               │ 112)              │            │ expanded_conv_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_e… │ (None, 14, 14,    │     75,264 │ expanded_conv_11… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_e… │ (None, 14, 14,    │      2,688 │ expanded_conv_12… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 14, 14,    │          0 │ expanded_conv_12… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 17, 17,    │          0 │ activation_33[0]… │
# │ (ZeroPadding2D)     │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 7, 7, 672) │     16,800 │ expanded_conv_12… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 7, 7, 672) │      2,688 │ expanded_conv_12… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 7, 7, 672) │          0 │ expanded_conv_12… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 672) │          0 │ activation_34[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 168) │    113,064 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 168) │          0 │ expanded_conv_12… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 672) │    113,568 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 1, 1, 672) │          0 │ expanded_conv_12… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_35 (ReLU)     │ (None, 1, 1, 672) │          0 │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_13         │ (None, 1, 1, 672) │          0 │ re_lu_35[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 7, 7, 672) │          0 │ activation_34[0]… │
# │ (Multiply)          │                   │            │ multiply_13[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_p… │ (None, 7, 7, 160) │    107,520 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_12… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_e… │ (None, 7, 7, 960) │    153,600 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_e… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 7, 7, 960) │          0 │ expanded_conv_13… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_d… │ (None, 7, 7, 960) │     24,000 │ activation_35[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_d… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 7, 7, 960) │          0 │ expanded_conv_13… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 960) │          0 │ activation_36[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 240) │    230,640 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 240) │          0 │ expanded_conv_13… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 960) │    231,360 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 1, 1, 960) │          0 │ expanded_conv_13… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_36 (ReLU)     │ (None, 1, 1, 960) │          0 │ add_14[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_14         │ (None, 1, 1, 960) │          0 │ re_lu_36[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 7, 7, 960) │          0 │ activation_36[0]… │
# │ (Multiply)          │                   │            │ multiply_14[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_p… │ (None, 7, 7, 160) │    153,600 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_a… │ (None, 7, 7, 160) │          0 │ expanded_conv_12… │
# │ (Add)               │                   │            │ expanded_conv_13… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_e… │ (None, 7, 7, 960) │    153,600 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_e… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 7, 7, 960) │          0 │ expanded_conv_14… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_d… │ (None, 7, 7, 960) │     24,000 │ activation_37[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_d… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 7, 7, 960) │          0 │ expanded_conv_14… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 960) │          0 │ activation_38[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 240) │    230,640 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 240) │          0 │ expanded_conv_14… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 960) │    231,360 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 1, 1, 960) │          0 │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_37 (ReLU)     │ (None, 1, 1, 960) │          0 │ add_15[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_15         │ (None, 1, 1, 960) │          0 │ re_lu_37[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 7, 7, 960) │          0 │ activation_38[0]… │
# │ (Multiply)          │                   │            │ multiply_15[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_p… │ (None, 7, 7, 160) │    153,600 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_a… │ (None, 7, 7, 160) │          0 │ expanded_conv_13… │
# │ (Add)               │                   │            │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1 (Conv2D)     │ (None, 7, 7, 960) │    153,600 │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1_bn           │ (None, 7, 7, 960) │      3,840 │ conv_1[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 7, 7, 960) │          0 │ conv_1_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 960)       │          0 │ activation_39[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 256)       │    246,016 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 256)       │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 3)         │        771 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,243,139 (12.37 MB)
#  Trainable params: 3,218,739 (12.28 MB)
#  Non-trainable params: 24,400 (95.31 KB)

# %%
def compile_model(lr: float):
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
        metrics=[
            "accuracy",
            tf.keras.metrics.TopKCategoricalAccuracy(k=2, name="top2_acc"),
            tf.keras.metrics.TopKCategoricalAccuracy(k=3, name="top3_acc"),

            # One-vs-rest PR-AUC over classes (macro-ish behavior)
            tf.keras.metrics.AUC(name="pr_auc_ovr", curve="PR", multi_label=True, num_labels=NUM_CLASSES),
        ],
    )

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score

class MacroPRCallback(tf.keras.callbacks.Callback):
    def __init__(self, val_ds, num_classes, name_prefix=""):
        super().__init__()
        self.val_ds = val_ds
        self.num_classes = num_classes
        self.name_prefix = name_prefix

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}

        y_true = []
        y_prob = []
        for xb, yb in self.val_ds:
            p = self.model.predict(xb, verbose=0)
            y_prob.append(p)
            y_true.append(np.argmax(yb.numpy(), axis=1))

        y_true = np.concatenate(y_true)
        y_prob = np.concatenate(y_prob, axis=0)
        y_pred = np.argmax(y_prob, axis=1)

        macro_prec = precision_score(y_true, y_pred, average="macro", zero_division=0)
        macro_rec = recall_score(y_true, y_pred, average="macro", zero_division=0)

        logs["precision"] = macro_prec
        logs["recall"] = macro_rec
        # Keras will automatically prefix val_? No—so we store them as val_precision/val_recall:
        logs["val_precision"] = macro_prec
        logs["val_recall"] = macro_rec

        print(f"\n[macro] val_precision={macro_prec:.4f} val_recall={macro_rec:.4f}")

macro_cb = MacroPRCallback(val_ds=val_ds, num_classes=NUM_CLASSES)

# %%
base_model.trainable = False
compile_model(LR_PHASE1)

callbacks_phase1 = [
    tf.keras.callbacks.EarlyStopping(monitor="val_pr_auc_ovr", mode="max", patience=3, restore_best_weights=True),
    macro_cb,
]

history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_PHASE1,
    callbacks=callbacks_phase1
)
# Out:
# Epoch 1/5
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 688ms/step - accuracy: 0.6742 - loss: 0.9181 - pr_auc_ovr: 0.7522 - top2_acc: 0.9068 - top3_acc: 1.0000
# [macro] val_precision=0.9139 val_recall=0.8600
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.7851 - loss: 0.6785 - pr_auc_ovr: 0.8751 - top2_acc: 0.9567 - top3_acc: 1.0000 - val_accuracy: 0.8750 - val_loss: 0.4912 - val_pr_auc_ovr: 0.9837 - val_top2_acc: 0.9881 - val_top3_acc: 1.0000 - precision: 0.9139 - recall: 0.8600 - val_precision: 0.9139 - val_recall: 0.8600
# Epoch 2/5
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 640ms/step - accuracy: 0.8582 - loss: 0.4734 - pr_auc_ovr: 0.9455 - top2_acc: 0.9848 - top3_acc: 1.0000
# [macro] val_precision=0.9433 val_recall=0.9133
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 35s 808ms/step - accuracy: 0.8896 - loss: 0.4315 - pr_auc_ovr: 0.9536 - top2_acc: 0.9888 - top3_acc: 1.0000 - val_accuracy: 0.9226 - val_loss: 0.3383 - val_pr_auc_ovr: 0.9918 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - precision: 0.9433 - recall: 0.9133 - val_precision: 0.9433 - val_recall: 0.9133
# Epoch 3/5
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 639ms/step - accuracy: 0.9191 - loss: 0.3680 - pr_auc_ovr: 0.9744 - top2_acc: 0.9939 - top3_acc: 1.0000
# [macro] val_precision=0.9622 val_recall=0.9467
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 41s 805ms/step - accuracy: 0.9418 - loss: 0.3292 - pr_auc_ovr: 0.9846 - top2_acc: 0.9963 - top3_acc: 1.0000 - val_accuracy: 0.9524 - val_loss: 0.2965 - val_pr_auc_ovr: 0.9952 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - precision: 0.9622 - recall: 0.9467 - val_precision: 0.9622 - val_recall: 0.9467
# Epoch 4/5
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 692ms/step - accuracy: 0.9472 - loss: 0.3110 - pr_auc_ovr: 0.9896 - top2_acc: 0.9973 - top3_acc: 1.0000
# [macro] val_precision=0.9554 val_recall=0.9418
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 38s 888ms/step - accuracy: 0.9507 - loss: 0.3025 - pr_auc_ovr: 0.9918 - top2_acc: 0.9970 - top3_acc: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.3097 - val_pr_auc_ovr: 0.9936 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - precision: 0.9554 - recall: 0.9418 - val_precision: 0.9554 - val_recall: 0.9418
# Epoch 5/5
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9446 - loss: 0.3153 - pr_auc_ovr: 0.9862 - top2_acc: 0.9958 - top3_acc: 1.0000
# [macro] val_precision=0.9622 val_recall=0.9467
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.9515 - loss: 0.3034 - pr_auc_ovr: 0.9890 - top2_acc: 0.9955 - top3_acc: 1.0000 - val_accuracy: 0.9524 - val_loss: 0.3210 - val_pr_auc_ovr: 0.9930 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - precision: 0.9622 - recall: 0.9467 - val_precision: 0.9622 - val_recall: 0.9467

# %%
base_model.trainable = True

for layer in base_model.layers:
    if isinstance(layer, tf.keras.layers.BatchNormalization):
        layer.trainable = False

for layer in base_model.layers[:-N_UNFROZEN]:
    layer.trainable = False

compile_model(LR_PHASE2)

callbacks_phase2 = [
    tf.keras.callbacks.EarlyStopping(monitor="val_pr_auc_ovr", mode="max", patience=5, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_pr_auc_ovr", mode="max", factor=0.5, patience=2, min_lr=1e-7),
    macro_cb,
]

history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_PHASE2,
    callbacks=callbacks_phase2
)
# Out:
# Epoch 1/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 645ms/step - accuracy: 0.9423 - loss: 0.3140 - pr_auc_ovr: 0.9877 - top2_acc: 0.9940 - top3_acc: 1.0000
# [macro] val_precision=0.9582 val_recall=0.9400
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 53s 864ms/step - accuracy: 0.9470 - loss: 0.3123 - pr_auc_ovr: 0.9884 - top2_acc: 0.9955 - top3_acc: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.3025 - val_pr_auc_ovr: 0.9952 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - learning_rate: 1.0000e-05 - precision: 0.9582 - recall: 0.9400 - val_precision: 0.9582 - val_recall: 0.9400
# Epoch 2/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 640ms/step - accuracy: 0.9590 - loss: 0.2972 - pr_auc_ovr: 0.9907 - top2_acc: 0.9997 - top3_acc: 1.0000
# [macro] val_precision=0.9582 val_recall=0.9400
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 33s 774ms/step - accuracy: 0.9590 - loss: 0.3027 - pr_auc_ovr: 0.9899 - top2_acc: 0.9993 - top3_acc: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.2994 - val_pr_auc_ovr: 0.9951 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - learning_rate: 1.0000e-05 - precision: 0.9582 - recall: 0.9400 - val_precision: 0.9582 - val_recall: 0.9400
# Epoch 3/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 640ms/step - accuracy: 0.9406 - loss: 0.3098 - pr_auc_ovr: 0.9896 - top2_acc: 0.9973 - top3_acc: 1.0000
# [macro] val_precision=0.9582 val_recall=0.9400
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 34s 791ms/step - accuracy: 0.9537 - loss: 0.2967 - pr_auc_ovr: 0.9919 - top2_acc: 0.9978 - top3_acc: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.3023 - val_pr_auc_ovr: 0.9951 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - learning_rate: 1.0000e-05 - precision: 0.9582 - recall: 0.9400 - val_precision: 0.9582 - val_recall: 0.9400
# Epoch 4/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 641ms/step - accuracy: 0.9516 - loss: 0.2984 - pr_auc_ovr: 0.9911 - top2_acc: 0.9993 - top3_acc: 1.0000
# [macro] val_precision=0.9582 val_recall=0.9400
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 34s 781ms/step - accuracy: 0.9567 - loss: 0.2939 - pr_auc_ovr: 0.9919 - top2_acc: 0.9985 - top3_acc: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.3042 - val_pr_auc_ovr: 0.9952 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-06 - precision: 0.9582 - recall: 0.9400 - val_precision: 0.9582 - val_recall: 0.9400
# Epoch 5/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - accuracy: 0.9581 - loss: 0.2980 - pr_auc_ovr: 0.9905 - top2_acc: 1.0000 - top3_acc: 1.0000
# [macro] val_precision=0.9582 val_recall=0.9400
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 33s 764ms/step - accuracy: 0.9582 - loss: 0.2934 - pr_auc_ovr: 0.9923 - top2_acc: 1.0000 - top3_acc: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.2986 - val_pr_auc_ovr: 0.9952 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - learning_rate: 5.0000e-06 - precision: 0.9582 - recall: 0.9400 - val_precision: 0.9582 - val_recall: 0.9400
# Epoch 6/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 681ms/step - accuracy: 0.9382 - loss: 0.3176 - pr_auc_ovr: 0.9848 - top2_acc: 0.9985 - top3_acc: 1.0000
# [macro] val_precision=0.9582 val_recall=0.9400
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 35s 814ms/step - accuracy: 0.9485 - loss: 0.3060 - pr_auc_ovr: 0.9889 - top2_acc: 0.9970 - top3_acc: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.2989 - val_pr_auc_ovr: 0.9952 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - learning_rate: 2.5000e-06 - precision: 0.9582 - recall: 0.9400 - val_precision: 0.9582 - val_recall: 0.9400
# Epoch 7/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 685ms/step - accuracy: 0.9432 - loss: 0.3121 - pr_auc_ovr: 0.9878 - top2_acc: 0.9971 - top3_acc: 1.0000
# [macro] val_precision=0.9582 val_recall=0.9400
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 42s 832ms/step - accuracy: 0.9530 - loss: 0.3005 - pr_auc_ovr: 0.9905 - top2_acc: 0.9963 - top3_acc: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.2995 - val_pr_auc_ovr: 0.9953 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - learning_rate: 2.5000e-06 - precision: 0.9582 - recall: 0.9400 - val_precision: 0.9582 - val_recall: 0.9400
# Epoch 8/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 691ms/step - accuracy: 0.9614 - loss: 0.2962 - pr_auc_ovr: 0.9926 - top2_acc: 0.9964 - top3_acc: 1.0000
# [macro] val_precision=0.9582 val_recall=0.9400
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 36s 836ms/step - accuracy: 0.9612 - loss: 0.2937 - pr_auc_ovr: 0.9923 - top2_acc: 0.9970 - top3_acc: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.2995 - val_pr_auc_ovr: 0.9952 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - learning_rate: 2.5000e-06 - precision: 0.9582 - recall: 0.9400 - val_precision: 0.9582 - val_recall: 0.9400
# Epoch 9/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 774ms/step - accuracy: 0.9553 - loss: 0.2962 - pr_auc_ovr: 0.9916 - top2_acc: 1.0000 - top3_acc: 1.0000
# [macro] val_precision=0.9582 val_recall=0.9400
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 40s 927ms/step - accuracy: 0.9567 - loss: 0.2950 - pr_auc_ovr: 0.9919 - top2_acc: 1.0000 - top3_acc: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.2978 - val_pr_auc_ovr: 0.9953 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - learning_rate: 2.5000e-06 - precision: 0.9582 - recall: 0.9400 - val_precision: 0.9582 - val_recall: 0.9400
# Epoch 10/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 712ms/step - accuracy: 0.9490 - loss: 0.3082 - pr_auc_ovr: 0.9873 - top2_acc: 0.9980 - top3_acc: 1.0000
# [macro] val_precision=0.9582 val_recall=0.9400
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 37s 862ms/step - accuracy: 0.9537 - loss: 0.3029 - pr_auc_ovr: 0.9891 - top2_acc: 0.9955 - top3_acc: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.2967 - val_pr_auc_ovr: 0.9952 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - learning_rate: 1.2500e-06 - precision: 0.9582 - recall: 0.9400 - val_precision: 0.9582 - val_recall: 0.9400
# Epoch 11/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 717ms/step - accuracy: 0.9634 - loss: 0.2970 - pr_auc_ovr: 0.9919 - top2_acc: 0.9999 - top3_acc: 1.0000
# [macro] val_precision=0.9582 val_recall=0.9400
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 37s 866ms/step - accuracy: 0.9701 - loss: 0.2842 - pr_auc_ovr: 0.9930 - top2_acc: 0.9993 - top3_acc: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.2956 - val_pr_auc_ovr: 0.9953 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - learning_rate: 1.2500e-06 - precision: 0.9582 - recall: 0.9400 - val_precision: 0.9582 - val_recall: 0.9400
# Epoch 12/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9608 - loss: 0.2928 - pr_auc_ovr: 0.9924 - top2_acc: 0.9914 - top3_acc: 1.0000
# [macro] val_precision=0.9582 val_recall=0.9400
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 36s 848ms/step - accuracy: 0.9590 - loss: 0.2885 - pr_auc_ovr: 0.9923 - top2_acc: 0.9955 - top3_acc: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.2957 - val_pr_auc_ovr: 0.9954 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - learning_rate: 6.2500e-07 - precision: 0.9582 - recall: 0.9400 - val_precision: 0.9582 - val_recall: 0.9400
# Epoch 13/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 714ms/step - accuracy: 0.9618 - loss: 0.2967 - pr_auc_ovr: 0.9930 - top2_acc: 0.9979 - top3_acc: 1.0000
# [macro] val_precision=0.9582 val_recall=0.9400
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 37s 862ms/step - accuracy: 0.9597 - loss: 0.2907 - pr_auc_ovr: 0.9928 - top2_acc: 0.9978 - top3_acc: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.2954 - val_pr_auc_ovr: 0.9954 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - learning_rate: 6.2500e-07 - precision: 0.9582 - recall: 0.9400 - val_precision: 0.9582 - val_recall: 0.9400
# Epoch 14/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 711ms/step - accuracy: 0.9576 - loss: 0.2940 - pr_auc_ovr: 0.9907 - top2_acc: 0.9978 - top3_acc: 1.0000
# [macro] val_precision=0.9582 val_recall=0.9400
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 37s 859ms/step - accuracy: 0.9612 - loss: 0.2874 - pr_auc_ovr: 0.9933 - top2_acc: 0.9985 - top3_acc: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.2952 - val_pr_auc_ovr: 0.9954 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - learning_rate: 3.1250e-07 - precision: 0.9582 - recall: 0.9400 - val_precision: 0.9582 - val_recall: 0.9400
# Epoch 15/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - accuracy: 0.9637 - loss: 0.2883 - pr_auc_ovr: 0.9934 - top2_acc: 0.9975 - top3_acc: 1.0000
# [macro] val_precision=0.9582 val_recall=0.9400
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 37s 853ms/step - accuracy: 0.9649 - loss: 0.2869 - pr_auc_ovr: 0.9935 - top2_acc: 0.9970 - top3_acc: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.2954 - val_pr_auc_ovr: 0.9954 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - learning_rate: 3.1250e-07 - precision: 0.9582 - recall: 0.9400 - val_precision: 0.9582 - val_recall: 0.9400
# Epoch 16/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 723ms/step - accuracy: 0.9465 - loss: 0.3088 - pr_auc_ovr: 0.9895 - top2_acc: 0.9950 - top3_acc: 1.0000
# [macro] val_precision=0.9582 val_recall=0.9400
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 37s 871ms/step - accuracy: 0.9545 - loss: 0.2934 - pr_auc_ovr: 0.9923 - top2_acc: 0.9978 - top3_acc: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.2953 - val_pr_auc_ovr: 0.9954 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - learning_rate: 1.5625e-07 - precision: 0.9582 - recall: 0.9400 - val_precision: 0.9582 - val_recall: 0.9400
# Epoch 17/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 699ms/step - accuracy: 0.9595 - loss: 0.2908 - pr_auc_ovr: 0.9927 - top2_acc: 0.9949 - top3_acc: 1.0000
# [macro] val_precision=0.9582 val_recall=0.9400
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 36s 846ms/step - accuracy: 0.9679 - loss: 0.2839 - pr_auc_ovr: 0.9932 - top2_acc: 0.9970 - top3_acc: 1.0000 - val_accuracy: 0.9464 - val_loss: 0.2953 - val_pr_auc_ovr: 0.9954 - val_top2_acc: 0.9940 - val_top3_acc: 1.0000 - learning_rate: 1.5625e-07 - precision: 0.9582 - recall: 0.9400 - val_precision: 0.9582 - val_recall: 0.9400

# %%
def merge_histories(h1, h2):
    merged = {}
    keys = set(h1.history.keys()) | set(h2.history.keys())
    for k in keys:
        merged[k] = list(h1.history.get(k, [])) + list(h2.history.get(k, []))
    return merged

merged = merge_histories(history1, history2)

plt.figure(figsize=(12, 7))

plt.subplot(2, 2, 1)
plt.plot(merged.get("accuracy", []), label="Train Accuracy")
plt.plot(merged.get("val_accuracy", []), label="Val Accuracy")
plt.legend(); plt.title("Accuracy")

plt.subplot(2, 2, 2)
plt.plot(merged.get("loss", []), label="Train Loss")
plt.plot(merged.get("val_loss", []), label="Val Loss")
plt.legend(); plt.title("Loss")

plt.subplot(2, 2, 3)
plt.plot(merged.get("precision", []), label="Train Precision (macro)")
plt.plot(merged.get("val_precision", []), label="Val Precision (macro)")
plt.legend(); plt.title("Precision (macro)")

plt.subplot(2, 2, 4)
plt.plot(merged.get("recall", []), label="Train Recall (macro)")
plt.plot(merged.get("val_recall", []), label="Val Recall (macro)")
plt.legend(); plt.title("Recall (macro)")

plt.tight_layout()
plt.show()

# %%
def report_and_cm_multiclass(ds, class_names, title=""):
    y_true = []
    y_probs = []

    for xb, yb in ds:
        probs = model.predict(xb, verbose=0)
        y_probs.append(probs)
        y_true.append(np.argmax(yb.numpy(), axis=1))

    y_probs = np.concatenate(y_probs, axis=0)
    y_true = np.concatenate(y_true, axis=0)
    y_pred = np.argmax(y_probs, axis=1)

    print("\n" + title)
    print(classification_report(y_true, y_pred, target_names=class_names, digits=4))

    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(7, 6))
    plt.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
    plt.title(f"Confusion Matrix - {title}")
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45, ha="right")
    plt.yticks(tick_marks, class_names)

    thresh = cm.max() / 2 if cm.max() > 0 else 0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, cm[i, j],
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")

    plt.ylabel("True label")
    plt.xlabel("Predicted label")
    plt.tight_layout()
    plt.show()

# TEST confusion matrix
report_and_cm_multiclass(test_ds, class_names, title="TEST")

# REAL-LIFE confusion matrix (if you have it)
if real_life_ds is not None:
    report_and_cm_multiclass(real_life_ds, class_names, title="REAL-LIFE")
# Out:
# TEST
#               precision    recall  f1-score   support
#
# aluminum_tin     1.0000    1.0000    1.0000        50
#       copper     0.9800    0.9800    0.9800        50
#        steel     0.9853    0.9853    0.9853        68
#
#     accuracy                         0.9881       168
#    macro avg     0.9884    0.9884    0.9884       168
# weighted avg     0.9881    0.9881    0.9881       168
# REAL-LIFE
#               precision    recall  f1-score   support
#
# aluminum_tin     0.7907    1.0000    0.8831        34
#       copper     1.0000    0.5333    0.6957        30
#        steel     0.7838    0.9062    0.8406        32
#
#     accuracy                         0.8229        96
#    macro avg     0.8582    0.8132    0.8064        96
# weighted avg     0.8538    0.8229    0.8104        96

# %%
print("\nDataset test evaluation:")
model.evaluate(test_ds, verbose=2)

if real_life_ds is not None:
    print("\nReal-life evaluation:")
    model.evaluate(real_life_ds, verbose=2)
# Out:
# Dataset test evaluation:
# 6/6 - 3s - 470ms/step - accuracy: 0.9881 - loss: 0.2550 - pr_auc_ovr: 0.9966 - top2_acc: 1.0000 - top3_acc: 1.0000
#
# Real-life evaluation:
# 3/3 - 2s - 821ms/step - accuracy: 0.8229 - loss: 0.4864 - pr_auc_ovr: 0.9545 - top2_acc: 0.9583 - top3_acc: 1.0000

# %%
def collect_probs_and_labels(ds):
    y_true = []
    y_prob = []
    for xb, yb in ds:
        p = model.predict(xb, verbose=0)  # (B, C)
        y_prob.append(p)
        y_true.append(yb.numpy())
    y_true = np.concatenate(y_true, axis=0)  # one-hot
    y_prob = np.concatenate(y_prob, axis=0)
    y_true_idx = np.argmax(y_true, axis=1)
    return y_true, y_true_idx, y_prob

cal_ds = real_life_ds if real_life_ds is not None else test_ds  # fallback, but real-life is strongly preferred
y_true_oh, y_true_idx, y_prob = collect_probs_and_labels(cal_ds)

print("Calibration dataset size:", len(y_true_idx))
# Out:
# Calibration dataset size: 96

# %%
def calibrate_uncertainty_thresholds(
    y_true_idx,
    y_prob,
    num_classes,
    t_grid=np.linspace(0.40, 0.90, 11),
    margin_grid=np.linspace(0.00, 0.30, 7),
    min_recall_per_class=0.70,   # increase as you collect more real-life images
):
    # Per-class threshold uses same t for all classes initially
    best = None

    p_sorted = np.sort(y_prob, axis=1)
    p1 = p_sorted[:, -1]
    p2 = p_sorted[:, -2]
    pred = np.argmax(y_prob, axis=1)

    for t in t_grid:
        for m in margin_grid:
            accept = (p1 >= t) & ((p1 - p2) >= m)
            coverage = float(np.mean(accept))

            # compute per-class recall among samples of that true class:
            ok = True
            recalls = []
            for c in range(num_classes):
                mask = (y_true_idx == c)
                if not np.any(mask):
                    # no samples of this class in calibration set -> can't constrain it
                    recalls.append(np.nan)
                    continue
                recall_c = float(np.mean((pred[mask] == c) & accept[mask]))
                recalls.append(recall_c)
                if recall_c < min_recall_per_class:
                    ok = False
                    break
            if not ok:
                continue

            candidate = {"t": float(t), "margin": float(m), "coverage": coverage, "recalls": recalls}
            if best is None or candidate["coverage"] > best["coverage"]:
                best = candidate

    return best

best_u = calibrate_uncertainty_thresholds(
    y_true_idx=y_true_idx,
    y_prob=y_prob,
    num_classes=NUM_CLASSES,
    min_recall_per_class=0.70
)

if best_u is None:
    print("No thresholds met constraints. Relax min_recall_per_class (e.g., 0.6) or collect more real-life images.")
else:
    print("Chosen uncertainty params:")
    print("  accept if max_prob >= t AND (p1 - p2) >= margin")
    print(f"  t = {best_u['t']:.2f}")
    print(f"  margin = {best_u['margin']:.2f}")
    print(f"  coverage = {best_u['coverage']:.3f}")
    for i, r in enumerate(best_u["recalls"]):
        print(f"  recall[{class_names[i]}] = {r}")
# Out:
# No thresholds met constraints. Relax min_recall_per_class (e.g., 0.6) or collect more real-life images.

# %%
def apply_uncertainty_policy(y_prob, t, margin):
    p_sorted = np.sort(y_prob, axis=1)
    p1 = p_sorted[:, -1]
    p2 = p_sorted[:, -2]
    pred = np.argmax(y_prob, axis=1)
    accept = (p1 >= t) & ((p1 - p2) >= margin)
    pred_or_uncertain = pred.copy()
    pred_or_uncertain[~accept] = -1
    return pred_or_uncertain, accept

if best_u is not None:
    pred_u, accept = apply_uncertainty_policy(y_prob, best_u["t"], best_u["margin"])
    print("Uncertain rate:", float(np.mean(~accept)))

    # confusion matrix on accepted only
    accepted_idx = np.where(accept)[0]
    if len(accepted_idx) > 0:
        y_true_acc = y_true_idx[accepted_idx]
        y_pred_acc = pred_u[accepted_idx]

        cm = tf.math.confusion_matrix(y_true_acc, y_pred_acc, num_classes=NUM_CLASSES).numpy()
        print("Confusion matrix (accepted samples only):")
        print(cm)
    else:
        print("No accepted samples under current thresholds.")

# %%
OUT_DIR = "./enhanced-model"
os.makedirs(OUT_DIR, exist_ok=True)

tflite_path = os.path.join(OUT_DIR, "stage3_metal_model.tflite")
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
with open(tflite_path, "wb") as f:
    f.write(tflite_model)
print("Saved TFLite model to:", tflite_path)

if best_u is not None:
    np.savez(
        os.path.join(OUT_DIR, "metal_uncertainty_params.npz"),
        t=best_u["t"],
        margin=best_u["margin"],
        class_names=np.array(class_names, dtype=object),
    )
    print("Saved uncertainty params.")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\VIRGIL~1\AppData\Local\Temp\tmp2de8d0gy\assets
# INFO:tensorflow:Assets written to: C:\Users\VIRGIL~1\AppData\Local\Temp\tmp2de8d0gy\assets
# Saved artifact at 'C:\Users\VIRGIL~1\AppData\Local\Temp\tmp2de8d0gy'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_207')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   1896242463312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243993888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243999520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243999344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243988080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244001808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242280432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242277616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242277792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242273040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242280256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242377328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242364656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242379616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242374864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242378208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242366592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242368176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242366064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242379264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242379792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896223706096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896279867088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896279863216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242905856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242912544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242906384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242906736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242919584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242915008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242905504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242905152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242906912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242913776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242907616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1895162229712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243568784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243568608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243566848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243562624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243561040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242592080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243561744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243571600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242578000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242593136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242592256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242578880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242586448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242584688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242582928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242850176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242844016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242854400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242855104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242850528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242848240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242840848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243745840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243746896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243749712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243752000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243747952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243750768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243755872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243752704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243754992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243756400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243364608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243367952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243370768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243373056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243369008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243371824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243377808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243378512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243378160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243250096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243258720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243264176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243262064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243256256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243261184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243254496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243642432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243645776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243643312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243642960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243649296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243651760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243654224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243649648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243652992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243649824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243658096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243710608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243712016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243716944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243719760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243722048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243718000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243720816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243721872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244038992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244041280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244037232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244040048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244045504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244048320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244050608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244046560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244049376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244050432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244138176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244140464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244136416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244139232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244141696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244144512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244146800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244142752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244145568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244146624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244202832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244203888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244200368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244203008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244206528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244209344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244211632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244207584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244210400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244214976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244316816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244314352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244314176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244316992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244320512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244323328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244325616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244321568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244324384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244328960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244381648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244379888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244382000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244381824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244385344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244388160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244390448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244386400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244389216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244393792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244495632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244394848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244393088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244494400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244499328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244502144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244504432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244500384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244503200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244509712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244506544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244508128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244510240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244593760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244596928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244599744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244602032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244597984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244600800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244606784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244607488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244607136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244659648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244665280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244668096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244670384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244666336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244669152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244672320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244774160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244673376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244671616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244772928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244777856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244780672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244782960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244778912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244781728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244787712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244788416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244788064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244840576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244846208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244849024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244851312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244847264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244850080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244851136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244972880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244973936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244970416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244973056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244978160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244980976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244983264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244979216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244982032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896244983088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896245069424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896245072944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896245074352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896245079280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896245082096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896245080864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896245080336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896245083152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283375216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283378032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283380320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283376272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283379088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283382960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1895096987392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283388064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283384016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283386832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283387888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283441456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283444976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283446384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283451312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283450784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283453072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283454480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283454656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283557552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283560368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283562656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283558608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283561424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283565296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283568112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283566880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283566352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283569168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283672944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283673648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283676464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283677872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283683504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283768960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283769488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283769312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283769136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283772656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896243568960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242280960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896283773712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896242371872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896240924272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896240935360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896240929200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1896224274944: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved TFLite model to: ./enhanced-model\stage3_metal_model.tflite
